# %%
import json
import pandas as pd
import re
import numpy as np
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_14648\2053825861.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open ('Archivos_IMDB/AccionWIP.json', 'r') as fichero:
    AccionWIP = json.load (fichero)

# %%
tupla_accionWip = [tuple(sublista) for sublista in AccionWIP]

# %%
tupla_accionWip[:1]
# Out:
# [('tt0113092',
#   'David Douglas, Tim Douglas',
#   'David Douglas, Christopher Salazar',
#   3.4,
#   '1h 40min',
#   'Earth is in a state of constant war and two colonies of humans have been sent to a far away world. The colonists create a new civilization but have inherited the worst traits of their forebears and war breaks out leaving the new cities in ruins. It falls to a bunch of teens to bring peace to the colony - but will they?')]

# %%
df_accion = pd.DataFrame(tupla_accionWip)

# %%
df_accion.to_csv('accion_IMDB8.csv', index=False)

# %%
# Lee los tres archivos CSV en DataFrames
df1 = pd.read_csv('accion_IMDB.csv')
df2 = pd.read_csv('accion_IMDB2.csv')
df3 = pd.read_csv('accion_IMDB3.csv')
df4 = pd.read_csv('accion_IMDB4.csv')
df5 = pd.read_csv('accion_IMDB5.csv')
df6 = pd.read_csv('accion_IMDB6.csv')
df7 = pd.read_csv('accion_IMDB7.csv')
df8 = pd.read_csv('accion_IMDB8.csv')
df9 = pd.read_csv('accion_IMDB1.csv')


# Combina los DataFrames en uno solo
df_IMDB_accion = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9], ignore_index=True)

# %%
df_IMDB_accion
# Out:
#                0                  1  \
# 0      tt0485535     Lalji B. Yadav
# 1      tt0772175  John Charles Hunt
# 2      tt0829150         Gary Shore
# 3      tt0831387     Gareth Edwards
# 4      tt0835775  Tristan Patterson
# ...          ...                ...
# 3645  tt11005524     Mauro Borrelli
# 3646  tt11023732       Venu Udugula
# 3647  tt11116912        Roar Uthaug
# 3648  tt11138512      Robert Eggers
# 3649  tt11151916       John V. Soto
#
#                                                2    3         4  \
# 0                                     K.K. Gupta  5.3  2h 16min
# 1                              John Charles Hunt  5.8  1h 40min
# 2       Matt Sazama, Burk Sharpless, Bram Stoker  6.2  1h 32min
# 3     Ishirô Honda, Takeo Murata, Shigeru Kayama  6.4   2h 3min
# 4                Timothy Ford, Tristan Patterson  4.6  1h 35min
# ...                                          ...  ...       ...
# 3645                                 Sean Wathen  NaN       NaN
# 3646                                Venu Udugula  6.7  2h 31min
# 3647                    Espen Aukan, Roar Uthaug  5.8  1h 41min
# 3648                         Sjón, Robert Eggers  7.0  2h 17min
# 3649  Adam Enslow, Dane Millerd, Andrew Slattery  5.3  1h 28min
#
#                                                       5
# 0                                             Dirección
# 1     A suburban woman witnesses her husbands murder...
# 2                                                   NaN
# 3                                                   NaN
# 4     A chronicle of the life of furniture salesman ...
# ...                                                 ...
# 3645  A police detective hunts down the elusive prof...
# 3646  Set against the backdrop of the Naxal movement...
# 3647                                                NaN
# 3648                                                NaN
# 3649                                                NaN
#
# [3650 rows x 6 columns]

# %%
accion_IMDB = df_IMDB_accion.drop_duplicates()

# %%
accion_IMDB
# Out:
#                0                  1  \
# 0      tt0485535     Lalji B. Yadav
# 1      tt0772175  John Charles Hunt
# 2      tt0829150         Gary Shore
# 3      tt0831387     Gareth Edwards
# 4      tt0835775  Tristan Patterson
# ...          ...                ...
# 3507  tt11005524     Mauro Borrelli
# 3508  tt11023732       Venu Udugula
# 3509  tt11116912        Roar Uthaug
# 3510  tt11138512      Robert Eggers
# 3511  tt11151916       John V. Soto
#
#                                                2    3         4  \
# 0                                     K.K. Gupta  5.3  2h 16min
# 1                              John Charles Hunt  5.8  1h 40min
# 2       Matt Sazama, Burk Sharpless, Bram Stoker  6.2  1h 32min
# 3     Ishirô Honda, Takeo Murata, Shigeru Kayama  6.4   2h 3min
# 4                Timothy Ford, Tristan Patterson  4.6  1h 35min
# ...                                          ...  ...       ...
# 3507                                 Sean Wathen  NaN       NaN
# 3508                                Venu Udugula  6.7  2h 31min
# 3509                    Espen Aukan, Roar Uthaug  5.8  1h 41min
# 3510                         Sjón, Robert Eggers  7.0  2h 17min
# 3511  Adam Enslow, Dane Millerd, Andrew Slattery  5.3  1h 28min
#
#                                                       5
# 0                                             Dirección
# 1     A suburban woman witnesses her husbands murder...
# 2                                                   NaN
# 3                                                   NaN
# 4     A chronicle of the life of furniture salesman ...
# ...                                                 ...
# 3507  A police detective hunts down the elusive prof...
# 3508  Set against the backdrop of the Naxal movement...
# 3509                                                NaN
# 3510                                                NaN
# 3511                                                NaN
#
# [2908 rows x 6 columns]

# %%
accion_IMDB.to_csv('accion_IMDB_clean.csv', index=False)

# %%
with open ('MuestraDrama.json', 'r') as fichero:
    MuestraDrama = json.load (fichero)

# %%
len(MuestraDrama)
# Out:
# 2779

# %%
with open ('InfoDrama.json', 'r') as fichero:
    InfoDrama= json.load (fichero)

# %%
len(InfoDrama)
# Out:
# 2779

# %%
lista_tuplas = []

# %%
for peli in InfoDrama:
    
    patron = re.compile(r'([a-z])([A-Z])')
    patron_duracion = re.compile(r'\b(?:\d+h\s*)?\d+min\b')
    tupla_datos = [peli[0],] 

    # listas intermedias para ir checkeando
    direccion = []
    guion = []
    nota = []
    duracion = []
    argumento = []
        
    for indice, linea in enumerate(peli[1]):
               
        
        # directores    
        if 'Dirección' in linea:
                                
            directores = patron.sub(r'\1, \2', peli[1][indice+1])
            direccion.append(directores)            


        # guionistas
        elif 'Guión' in linea:
            
            guionistas = patron.sub(r'\1, \2', peli[1][indice+1])
            guion.append(guionistas)
                
        
        # nota y duracion
        elif 'PUNTUACIÓN EN IMDb' in linea:
            nota.append(float(peli[1][indice+1].replace(',', '.')))
            
            if r'\d+h' or r'\d+min' in peli[1][indice-1]:  
                duracion.append(peli[1][indice-1])
            
                    
        # argumento
        elif 'Añade un argumento en tu idioma' in linea:
            argumento.append(peli[1][indice+1])

    # añadimos a la tupla los datos de la lista intermedia
    for elemento in [direccion, guion, nota, duracion, argumento]:
        if elemento != []:
            tupla_datos.append(elemento[0])
        else:
            tupla_datos.append(np.nan)
    
    lista_tuplas.append(tupla_datos)

# %%
lista_tuplas
# Out:
# [['tt0113092',
#   'David Douglas, Tim Douglas',
#   'David Douglas, Christopher Salazar',
#   3.4,
#   '1h 40min',
#   'Earth is in a state of constant war and two colonies of humans have been sent to a far away world. The colonists create a new civilization but have inherited the worst traits of their forebears and war breaks out leaving the new cities in ruins. It falls to a bunch of teens to bring peace to the colony - but will they?'],
#  ['tt0113092',
#   'David Douglas, Tim Douglas',
#   'David Douglas, Christopher Salazar',
#   3.4,
#   '1h 40min',
#   'Earth is in a state of constant war and two colonies of humans have been sent to a far away world. The colonists create a new civilization but have inherited the worst traits of their forebears and war breaks out leaving the new cities in ruins. It falls to a bunch of teens to bring peace to the colony - but will they?'],
#  ['tt0113086',
#   'Michael New',
#   nan,
#   6.8,
#   '2000',
#   "Florentino is a young horseman and singer, a free spirit living in the open world without restrictions, in the Venezuelan plains. He confronts the devil in a duel of improvised verses. As time passes, these unspoilt plains start to change. Through Florentino's voice and actions, the plains cannot be conquered. Its culture defies the devil in the eternal fight between ... Leer todo"],
#  ['tt0116748',
#   'Rakesh Roshan',
#   'Sachin Bhowmick, Ravi Kapoor, Sagar Sarhadi',
#   3.7,
#   '3h',
#   "Wealthy Rajiv Sinha and middle-classed Amar Saxena are two childhood friends, with similar likes, and tastes. Their similar habits lead them to being in love with the same woman - Seema, who loves Amar, and is willing to marry him no matter what. Rajiv attempts to offer money to Sapna's guardian so that he can marry her, in vain though. When Rajiv attempts to convince... Leer todo"],
#  ['tt0115874',
#   'Marcos Manhães Marins',
#   'Marcos Manhães Marins',
#   nan,
#   nan,
#   'Dirección'],
#  ['tt0116391', 'Mazhar Khan', nan, 6.2, '2h 47min', nan],
#  ['tt0118694', 'Kar-Wai Wong', 'Kar-Wai Wong', 8.1, '1h 38min', nan],
#  ['tt0118710',
#   'George Bazala',
#   'George Bazala, Patrick Clarke',
#   6.3,
#   '1h 36min',
#   'A young Irishman enters the US illegally with his wayward friend Seamus. Landing in New York the pair start out with dreams of striking it rich but soon find themselves in dead-end jobs and drifting apart. As Seamus pursues various get-rich schemes, the more cautious Patrick finds himself devoting time to looking after Tom, an Irish author down on his luck, and courti... Leer todo'],
#  ['tt0118852',
#   'Al Pacino',
#   'Ira Lewis',
#   7.1,
#   '1h 39min',
#   "Harry and Jake, two unsuccessful writers, spend a cathartic evening arguing about money, aesthetics, their friendship, and Harry's new manuscript."],
#  ['tt0119866',
#   'Bruno Nuytten',
#   'Bruno Nuytten',
#   5.4,
#   '1h 44min',
#   "Faustine,now an adult ,wants to know all about her father's death;she learns he was once in love with a fifteen-year-old girl ,Alice ."],
#  ['tt0119495',
#   'Adrian Fulle',
#   'Adrian Fulle, David J. Miller, Daniel Bingley',
#   5.0,
#   '1h 26min',
#   'A group of raucous college buds living the Dorm life, decide to have a blowout while most of their friends are away for the Thanksgiving holiday. With LOVE 101 being the toughest course this semester, will they pass the final exam?'],
#  ['tt0119966',
#   'Dorian Ramírez',
#   'Dorian Ramírez',
#   6.6,
#   '1h 15min',
#   'Dirección'],
#  ['tt0120202',
#   'David Mamet',
#   'David Mamet',
#   6.7,
#   '1h 45min',
#   'A movie crew invades a small town whose residents are all too ready to give up their values for showbiz glitz.'],
#  ['tt0120467',
#   'Bryan Johnson',
#   'Bryan Johnson',
#   5.2,
#   '1h 27min',
#   "A man who performs as a children's birthday party clown tries to piece his life back together after being gang-raped."],
#  ['tt0123003', 'Shirley Mac, Laine', 'David Ciminello', 6.0, '1h 48min', nan],
#  ['tt0122161',
#   'Kikuo Kawasaki',
#   'Kikuo Kawasaki',
#   4.9,
#   '1h 39min',
#   "The entangled stories around the life of Elsie Taryn Townsendz, who becomes rich from being a country town's girl."],
#  ['tt0120117',
#   'N. Chandra',
#   'N. Chandra, Rajeev Kaul, Praful Parekh',
#   4.7,
#   '2h 40min',
#   'Filled with vengeance, a simple man turns into a hardcore criminal in order to avenge the destruction of his family.'],
#  ['tt0120626',
#   'Maria de Medeiros',
#   'Maria de MedeirosÈve Deboise',
#   7.1,
#   '2h 3min',
#   nan],
#  ['tt0120263', 'Roy Andersson', 'Roy Andersson', 7.5, '1h 38min', nan],
#  ['tt0120753', 'Wim Wenders', 'Nicholas Klein, Bono', 5.7, '2h 2min', nan],
#  ['tt0120630',
#   'Peter Lord, Nick Park',
#   'Peter Lord, Nick Park, Karey Kirkpatrick',
#   7.1,
#   '1h 24min',
#   nan],
#  ['tt0120698',
#   'Keoni Waxman',
#   'Richard Beattie',
#   4.4,
#   '1h 34min',
#   'A dark, comedic thriller about fraud, bank robbers, and a search for love.'],
#  ['tt0122459',
#   'Bonnie Hunt',
#   'Bonnie Hunt, Don Lake, Andrew Stern',
#   6.9,
#   '1h 55min',
#   "A man who falls in love with the woman who received his wife's heart must decide which woman it is who holds his heart."],
#  ['tt0127349',
#   'Keith Gordon',
#   'Scott Spencer, Robert Dillon',
#   6.4,
#   '1h 45min',
#   'A congressional candidate questions his sanity after seeing the love of his life, presumed dead, suddenly emerge.'],
#  ['tt0130623',
#   'Eric Leighton, Ralph Zondag',
#   'Thom Enriquez, John Harrison, Robert Nelson Jacobs',
#   6.4,
#   '1h 22min',
#   nan],
#  ['tt0134630',
#   'Bruce Paltrow',
#   'John Byrum',
#   6.1,
#   '1h 52min',
#   'A professional karaoke hustler reconnects with his daughter and a bored suburban businessman turns outlaw karaoke singer, among other plotlines.'],
#  ['tt0133752',
#   'Ron Cosentino',
#   'Ron Cosentino',
#   6.5,
#   '1h 40min',
#   'Transplanted from New York, Duke and his brother Frankie Romano live in a rundown LA apartment with their alcoholic mother (Karen Black).'],
#  ['tt0135707',
#   'Tom Shell',
#   'Nicholas Wilson, Elizabeth Hansen',
#   6.3,
#   '1h 37min',
#   "The 1854 Wyoming historical drama is based on Tom Shell's adaptation of the true life memoirs of Pony Express rider Nick Wilson."],
#  ['tt0138353',
#   'Adrian Pasdar',
#   'Justin Monjo',
#   5.7,
#   '1h 37min',
#   "What's the bond between partners, between brothers, and between spouses? In L.A., Bill Holt handcuffs Sean Rickhart inside a rebar frame for a freeway pillar at a construction site; Bill's going to bury Sean in quick-drying cement. Guided by the narration of Nin, Bill's coke-snorting partner, we go back and forth over the past 48 hours to find out what brings Bill and... Leer todo"],
#  ['tt0138927',
#   'Barry Berman',
#   'Barry Berman',
#   6.5,
#   '1h 35min',
#   'A mother flees to her hometown after her son gets into trouble.'],
#  ['tt0138655',
#   'Ayanna Floyd',
#   'Ayanna Floyd',
#   nan,
#   nan,
#   "An unhappy country music disc jockey's life changes when she meets a man in a convenience store."],
#  ['tt0138946', 'James Gray', 'James Gray, Matt Reeves', 6.4, '1h 55min', nan],
#  ['tt0138818',
#   'Douglas Green',
#   'Mitch Giannunzio',
#   6.5,
#   '1h 37min',
#   'A son visits his aging mother and sees tragic, intermittent signs of senility, but she pleads with him not to send her to a sanitarium.'],
#  ['tt0139500', 'Pedro Costa', nan, 7.0, '2h 51min', nan],
#  ['tt0141399',
#   'Andrew Bergman',
#   'Michael Korda, Paul Rudnick',
#   5.3,
#   '1h 35min',
#   'Bette Midler and Nathan Lane star in this comedy about Jacqueline Susann, the ambitious woman of dubious talent who wrote Valley of the Dolls, a best-selling novel that became a sensation.'],
#  ['tt0143344',
#   'Lorenzo Doumani',
#   'Lorenzo Doumani, Mark Stevens',
#   4.1,
#   '1h 39min',
#   'Inspired by her father, a former boxer whose family duties superseded his athletic ambitions, a young woman (Sophia Adella Hernandez) decides to enter the sport.'],
#  ['tt0144142',
#   'Lisa Krueger',
#   'Lisa Krueger',
#   5.1,
#   '1h 38min',
#   'A young woman goes in search of her midlife crisis suffering husband who left her.'],
#  ['tt0144084',
#   'Mary Harron',
#   'Bret Easton Ellis, Mary Harron, Guinevere Turner',
#   7.6,
#   '1h 42min',
#   nan],
#  ['tt0142155',
#   'Christopher Gotschall',
#   nan,
#   6.0,
#   '21min',
#   "Jamie, an aspiring photographer and clumsy romantic, falls for his friend William, a pre-med student who's involved in a long-term relationship with an older man. Shared dance lessons and shared wine lead to shared beds. William wants Jamie but won't leave his partner. Confronting William and confronted by William's partner, Jamie begins to sort out the difference bet... Leer todo"],
#  ['tt0144613',
#   'Sebastián Lelio, Marialy Rivas',
#   'Sebastián Lelio, Marialy Rivas',
#   nan,
#   nan,
#   'Technoculture and social restrictions, in Santiago de Chile, at the end of the millenium.'],
#  ['tt0146309',
#   'Roger Donaldson',
#   'David Self, Ernest R. May, Philip D. Zelikow',
#   7.3,
#   '2h 25min',
#   nan],
#  ['tt0146882',
#   'Stephen Frears',
#   'Nick Hornby, D.V. De, Vincentis, Steve Pink',
#   7.4,
#   '1h 53min',
#   nan],
#  ['tt0146984',
#   'Robert Redford',
#   'Steven Pressfield, Jeremy Leven',
#   6.7,
#   '2h 6min',
#   nan],
#  ['tt0148421',
#   'Martin Davidson',
#   'Jeffrey Goldenberg, Robert Held, Martin Davidson',
#   6.6,
#   '1h 37min',
#   "The lead singer of an oldies group reminisces about the good ol' days and a potential comeback."],
#  ['tt0149624',
#   'Billy Bob Thornton',
#   'Cormac Mc, Carthy, Ted Tally',
#   5.8,
#   '1h 56min',
#   nan],
#  ['tt0149367',
#   'Marek Kanievska',
#   'E. Max Frye, Topper Lilien, Carroll Cartwright',
#   6.3,
#   '1h 29min',
#   nan],
#  ['tt0151150',
#   'Mansoor Khan',
#   'Aatish Kapadia, Mansoor Khan, Nidhi Tuli',
#   6.1,
#   '2h 42min',
#   "Max, who lives with his twin sister Shirley in Goa, is enraged when he finds out that she has fallen in love with Rahul, his bitter rival Prakash's younger brother."],
#  ['tt0153012',
#   'L.P. Brown IIIJohn Sjogren',
#   'L.P. Brown III',
#   4.0,
#   '1h 24min',
#   'Jack (an ex P.I.) steals a briefcase from local mobsters. A stripper joins him on the run. Other local mob groups are also interested in the contents of the briefcase.'],
#  ['tt0153100',
#   'Francis Delia',
#   'Francis Delia, Norman Mailer',
#   7.2,
#   '1h 33min',
#   'A thirty-something Irish-American former matador teaches a bull-fighting class in Greenwich Village. After the sexual conquest of a number of his female students, he meets his match in a 19-year-old co-ed.'],
#  ['tt0153464',
#   'Philip Haas',
#   'W. Somerset Maugham, Belinda Haas',
#   6.0,
#   '1h 55min',
#   'A widow finds choosing a new husband might not be her choice at all, as the actions of her various prospects confine her freedom.'],
#  ['tt0155723',
#   'Katherine Dieckmann',
#   'Katherine Dieckmann, Leon Rooke',
#   6.8,
#   '1h 27min',
#   "A young loner wandering the back roads of North Carolina comes across an abandoned baby. He immediately starts seeking the baby's parents, but starts developing a bond with the child that explores his own isolated roots."],
#  ['tt0155754', 'Bob Clark', 'Mark Sanderson', 6.3, '1h 30min', nan],
#  ['tt0155150',
#   'Adele Bertei',
#   'James Campbell',
#   4.8,
#   '1h 39min',
#   "After a rich woman dies, her friends and relatives meet at her mansion to await the reading of her will. Over the evening, many of them hook up and have a passionate night together, including the maid. But someone's watching them."],
#  ['tt0157202',
#   'Glenn Klinker',
#   'Glenn Klinker',
#   4.8,
#   '1h 30min',
#   'A deranged street person has flashes of sanity, and his outrage at, and disgust for, the nightly news body count inspires him to vanquish not only his inner demons, but also the very real ones that are preying, unchecked upon the innocent.'],
#  ['tt0156841', 'John Schlesinger', 'Tom Ropelewski', 4.7, '1h 48min', nan],
#  ['tt0156942',
#   'Ron Krauss',
#   'Oona Croese, Ron Krauss, Mario Zavala',
#   5.4,
#   '1h 25min',
#   'Kids go to a rave and not all of them make it home the next day.'],
#  ['tt0156812',
#   'Jay Russell',
#   'Willie Morris, Gail Gilchriest',
#   7.0,
#   '1h 35min',
#   nan],
#  ['tt0156757',
#   'John Forte',
#   'John Forte',
#   5.9,
#   '1h 32min',
#   'A Catholic high-school student trying to perfect his soccer timing by practicing dance falls in love with his dance partner.'],
#  ['tt0157122', 'Liv Ullmann', 'Ingmar Bergman', 7.4, '2h 34min', nan],
#  ['tt0158033',
#   'Pat Murphy',
#   'Brenda Maddox, Pat Murphy, Gerard Stembridge',
#   5.9,
#   '1h 46min',
#   "Dublin, 1904, James Joyce chats up Nora Barnacle, a hotel maid recently come from Galway. She enchants him with her frank, uninhibited manner, and before long, he's convinced her to come with him to Trieste."],
#  ['tt0159371',
#   'Christopher Robin Hood',
#   'Christopher Robin Hood',
#   7.3,
#   '1h 30min',
#   "Rob's successful life is interrupted when he crosses paths with smart beautiful Leslie. After being suddenly and mistakenly arrested, Rob begins a city-wide search for the woman of his dreams unsure of her last name or where to find her."],
#  ['tt0158871',
#   'Aage Rais-Nordentoft',
#   'Jens Dahl, Aage Rais-Nordentoft',
#   5.5,
#   '1h 33min',
#   "A Sergeant in the UN peacekeeping force in Bosnia charges money to take some gun toting civilians on a guided tour to shoot some real Serbs 'for the excitement of it'. Fatal events unfold, revealing the starkness of war and armed strife."],
#  ['tt0160495',
#   'Paul Nicholas',
#   'Brendan Beseth',
#   4.7,
#   '1h 41min',
#   'Kirsten Dunst plays a young woman (Lidda), who is searching for her father (James Caan). She finds herself at odds with her boyfriend who wants nothing but a carefree lifestyle.'],
#  ['tt0160547',
#   'Michael Browning',
#   'Michael Browning',
#   4.9,
#   '1h 32min',
#   'A series of mishaps and misfortunes over $1 million in cash leads to murder, mayhem and greed.'],
#  ['tt0160550',
#   'Aleksandr Zeldovich',
#   'Vladimir Sorokin, Aleksandr Zeldovich',
#   6.3,
#   '2h 19min',
#   'The film centres on Mike, a businessman in decidedly the new Russian mould. When Mike gets stung on a deal, his suspicions immediately fall on Lev, who receives the customary torture to make him reveal where the money has gone.'],
#  ['tt0160663',
#   'Martin Schenk',
#   'Martin Schenk',
#   5.5,
#   '1h 28min',
#   'Four teenagers pull a prank that goes awry.'],
#  ['tt0160644',
#   'Alain Berliner',
#   'Ron Bass, David Field',
#   5.5,
#   '1h 45min',
#   'A psychological romantic thriller where fantasy and reality become indistinguishable for a woman leading a double life in her dreams.'],
#  ['tt0160289',
#   'Paul Rachman',
#   'Shawn David Thompson, William Quist',
#   5.5,
#   '1h 37min',
#   'Four friends steal a valuable statuette for a dangerous black market art dealer, lose it, and are forced to play a deadly bluffing game to save their lives.'],
#  ['tt0159784',
#   'Joe Chappelle',
#   'Tsutomu Shimomura, John Markoff, David Newman',
#   6.2,
#   '1h 32min',
#   nan],
#  ['tt0161216',
#   'Robert Greenwald',
#   'Anita Hoffman, Abbie Hoffman, Marty Jezer',
#   6.4,
#   '1h 46min',
#   nan],
#  ['tt0160759',
#   'António Ferreira',
#   'António Ferreira',
#   6.6,
#   '45min',
#   "What stops two people from being together? A third one. What stops one person from fighting for another? Nothing. Pedro lives in the suburbs, where he works with his father in a garage. Everyday he takes the bus downtown where he goes to school and meets his friends. It's summertime and they all go down to the river where they spend their free time or even their schoo... Leer todo"],
#  ['tt0160484',
#   'Janusz Kaminski',
#   'Pierce Gardner, Betsy Stahl',
#   4.8,
#   '1h 37min',
#   nan],
#  ['tt0160797',
#   'William Friedkin',
#   'Jim Webb, Stephen Gaghan',
#   6.4,
#   '2h 8min',
#   nan],
#  ['tt0160749',
#   'Tag Purvis',
#   'Tag Purvis',
#   6.1,
#   '1h 50min',
#   "Red Dirt offers the story of a young man's search to belong in this sublime expression of love and reconciliation. At only twenty, Griffith is struggling with the responsibilities of caring for his unwell aunt, grieving the loss of their family's matriarch, and his own dreams of leaving Pine Apple. With the arrival of a stranger, Griffith's carefully constructed walls... Leer todo"],
#  ['tt0161003',
#   'Rel Dowdell',
#   'Rel Dowdell',
#   5.1,
#   '1h 33min',
#   'What started out as an innocent night of fun and games with upperclassmen and younger freshman college women turns into lies betrayal and an ultimate journey on the train ride'],
#  ['tt0160616',
#   'Dan Mc, Cormack',
#   'Dan Mc, Cormack',
#   5.7,
#   '1h 44min',
#   'This stylized turn-of-the-millennium thriller follows troubled couple Phil and Anna, each suspecting the other of infidelity, as they try to keep their paranoia and distrust from further fracturing the strange world around them.'],
#  ['tt0162222', 'Robert Zemeckis', 'William Broyles Jr.', 7.8, '2h 23min', nan],
#  ['tt0161081',
#   'Robert Zemeckis',
#   'Clark Gregg, Sarah Kernochan',
#   6.6,
#   '2h 10min',
#   nan],
#  ['tt0162983',
#   'Diane Keaton',
#   'Delia Ephron, Nora Ephron',
#   4.8,
#   '1h 34min',
#   nan],
#  ['tt0163125',
#   'Jon Dichter',
#   'Jon Dichter',
#   5.3,
#   '1h 42min',
#   'A telephone operator takes revenge an a rude customer by ruining his credit rating, his reputation, and his marriage.'],
#  ['tt0162901',
#   'Mariano Barroso',
#   'Mariano Barroso, Luis Marías, Joaquín Notario',
#   5.8,
#   '1h 35min',
#   nan],
#  ['tt0164182',
#   'Stephen Erickson',
#   'Stephen Erickson',
#   8.3,
#   '1h 35min',
#   'A heart-hardened son returns home to keep a promise to his dying father, a master stonecutter. This story touches a universal chord as it explores the passing on of an artistic legacy in spite of the dark shadows of an unresolved past.'],
#  ['tt0164212',
#   'Stephen Hopkins',
#   'John Wainwright, Claude Miller, Jean Herman',
#   6.4,
#   '1h 50min',
#   nan],
#  ['tt0163983',
#   'Chuck Russell',
#   'Cathy Cash Spellman, Thomas Rickman, Clifford Green',
#   5.1,
#   '1h 47min',
#   nan],
#  ['tt0163676',
#   'Mary Lambert',
#   'Mark Gibson, Philip Halprin',
#   4.6,
#   '1h 45min',
#   "A mentally disturbed young woman takes a job at a posh country club and falls in with a clique of wealthy college kids where she's taken under the wing of the clique's twisted leader, who harbors some dark secrets too terrifying to tell."],
#  ['tt0163978',
#   'Danny Boyle',
#   'John Hodge, Alex Garland',
#   6.6,
#   '1h 59min',
#   nan],
#  ['tt0163745',
#   'Gene Cajayon',
#   'Gene Cajayon, John Manal Castro',
#   6.4,
#   '1h 34min',
#   "A young man struggles with his desire to study art when his family thinks he's headed for premedical studies. Conflicts between Filipino traditions and expectations vs. personal dreams in the contemporary world erupt at his sister's debut."],
#  ['tt0164318',
#   'Martin Spottl',
#   'Sigal Erez, Martin Spottl',
#   5.5,
#   '1h 39min',
#   'A small-town sheriff falls in love with a Latina illegal immigrant who witnessed a murder on the Texas border.'],
#  ['tt0164545',
#   'William R. Greenblatt',
#   'Andrew Stein',
#   3.7,
#   '1h 29min',
#   'After his wife is killed researching a deadly virus, a doctor, out of anger and guilt, infects himself with the virus and threatens the world.'],
#  ['tt0165642',
#   'Rafael Eisenman',
#   "Zalman King, Elise D'Haene",
#   3.2,
#   '1h 25min',
#   "Gabe, a photographer, his assistant, Annie, and his boss hire a ship to take them out to sea on a modeling shoot. What Gabe doesn't know is that an old friend-turned-enemy of his has indirectly lured him into the situation, and the models that were hired locally are skilled weapons handlers and dealers. The ship is on its way to meet a South African submarine to whom ... Leer todo"],
#  ['tt0166013',
#   'John Mackenzie',
#   'Guy Andrews, Ronan Gallagher, Colum Mc, Cann',
#   6.4,
#   '1h 47min',
#   'Irish crime-investigating reporter Sinead Hamilton invades the Irish underworld and attempts to expose the illegitimate activities that she has found. Hampered by the system, a police consort is ineffectual at aiding her despite trying to step outside of the normal bounds. Her husband, who hates her activities and the danger she places herself in, grudgingly admires h... Leer todo'],
#  ['tt0165800',
#   'Cameron Thor',
#   'Tiffany Salerno, Tim Puntillo',
#   3.9,
#   '1h 29min',
#   'Nine former schoolmates are invited to a cabin for a reunion, but their hostess commits suicide. They all try to figure out why.'],
#  ['tt0167183',
#   'Irene Turner',
#   'Amanda L. Beall',
#   4.8,
#   '1h 41min',
#   "Grace and her roommate Casey don't get along. Grace is in a happy relationship with Charlie and they are planning to get married soon and that frustrated Casey because she thinks Grace just has everything. As the time goes by their relationships will get more complicated and nothing will be as it seemed..."],
#  ['tt0168446',
#   'Hans Petter Moland',
#   'Hans Petter Moland, Kristin Amundsen, Lars Bill Lundholm',
#   7.1,
#   '1h 53min',
#   "A mom dying in Aberdeen, Scotland, asks her coke snorting, nympho, London lawyer daughter to get her estranged, alcoholic dad in Oslo, Norway, to Aberdeen. He's drunk at the airport, so they travel together by car and ferry."],
#  ['tt0168629', 'Lars von Trier', 'Lars von Trier, Sjón', 7.9, '2h 20min', nan],
#  ['tt0168509', 'Gabriel Auer', 'Gabriel Auer', 6.2, '1h 24min', 'Dirección'],
#  ['tt0167203',
#   'Hugh Hudson',
#   'Kuki Gallmann, Paula Milne, Susan Shilliday',
#   5.5,
#   '1h 54min',
#   nan],
#  ['tt0167380',
#   'Aleksandr Proshkin',
#   'Alexander Pushkin, Galina Arbuzova, Stanislav Govorukhin',
#   6.6,
#   '2h 10min',
#   'A historical drama based on the novel of the same name.'],
#  ['tt0169324', 'Kevin Tenney', 'Kevin Tenney', 5.6, '1h 35min', nan],
#  ['tt0168612',
#   'Greg Morgan',
#   'Robert David Cochrane',
#   5.3,
#   '1h 37min',
#   "A gritty tale of how the game of life plays out in Inglewood, California. When a pickup basketball game turns deadly, Reggie seeks revenge as he tracks down his best friend's killers. When Reggie locates who he believes are the perpetrators, everyone around wants to ensure the matter is handled fairly and without any additional bloodshed."],
#  ['tt0169122',
#   'Jag Mundhra',
#   'Thomas A. Fucci, Randor Guy',
#   3.5,
#   '1h 35min',
#   nan],
#  ['tt0168856',
#   'Stefan Fjeldmark, Greg Manwaring, Michael Donovan',
#   'Tracy J. Brown, Stefan Fjeldmark, Karsten Kiilerich',
#   6.0,
#   '1h 20min',
#   'Three children accidentally get turned into fish after drinking a potion made by an eccentric scientist. When the kids end up in the sea, they must find the antidote within 48 hours or remain as fish forever.'],
#  ['tt0168504',
#   'Scott Wiper',
#   'Scott Wiper',
#   5.6,
#   '1h 41min',
#   'A Chicago cop quits the force and finds himself threatened by the Mafia.'],
#  ['tt0168631', 'Gregory Marquette', 'Gregory Marquette', 4.7, '1h 30min', nan],
#  ['tt0171433', 'Edward Norton', 'Stuart Blumberg', 6.4, '2h 8min', nan],
#  ['tt0171359',
#   'Michael Almereyda',
#   'William Shakespeare, Michael Almereyda',
#   5.9,
#   '1h 52min',
#   "Modern-day New York City adaptation of Shakespeare's immortal story about Hamlet's plight to avenge his father's murder."],
#  ['tt0170452',
#   'John Leekley',
#   'John Leekley, Evan Rhodes',
#   5.1,
#   '1h 49min',
#   'A young boy sets out to find his mother. After setting up camp in Central Park, he encounters a group of people even needier than himself.'],
#  ['tt0170691',
#   'Joel Schumacher',
#   'Ross Klavan, Michael Mc, Gruther',
#   6.9,
#   '1h 41min',
#   nan],
#  ['tt0172495',
#   'Ridley Scott',
#   'David Franzoni, John Logan, William Nicholson',
#   8.5,
#   '2h 35min',
#   nan],
#  ['tt0171580',
#   'Neil La, Bute',
#   'John C. Richards, James Flamberg',
#   6.3,
#   '1h 50min',
#   nan],
#  ['tt0172699',
#   'Tracy Alexson',
#   'Tracy Alexson',
#   4.6,
#   '1h 30min',
#   "Sarah and Ryan were a great couple. They had their fun together, but the man's fear of commitment pushed the woman away. Yet the situation between them isn't over because Sarah is pregnant and she's trying to find ways to hide this news from Ryan and everyone else - except her best friend, who probably won't be of much help in this matter."],
#  ['tt0172632',
#   'Stanley Tucci',
#   'Joseph Mitchell, Howard A. Rodman',
#   6.6,
#   '1h 44min',
#   "Around 1940, The New Yorker staff writer Joe Mitchell meets Joe Gould, a Greenwich Village character, who is writing a voluminous Oral History of the World, a record of twenty thousand conversations he's overheard."],
#  ['tt0173999',
#   'Tony Barbieri',
#   'Tony Barbieri',
#   6.3,
#   '1h 40min',
#   "A 10-year-old boy shares an intense bond with his mentally ill mother. The youth's life is turned upside down when his mother lapses into violent psychosis. A former psychiatrist takes pity on, and then custody of, the child."],
#  ['tt0174027',
#   'Mohamed Rachid Benhadj',
#   'Mohamed Rachid Benhadj',
#   6.4,
#   '1h 47min',
#   nan],
#  ['tt0174480', 'Joan Chen', 'Allison Burnett', 5.6, '1h 43min', nan],
#  ['tt0174646',
#   'Gil Brenton',
#   'Gil Brenton',
#   6.5,
#   '1h 19min',
#   'A beautiful woman comes between a father and son.'],
#  ['tt0176578',
#   'Jimmy Bridges, Todd Bridges',
#   'Jimmy Bridges, Todd Bridges',
#   6.9,
#   '45min',
#   'A short film about the rise, fall and rise of child star Todd Bridges (Arnold (1978)).'],
#  ['tt0176783',
#   'Davis Guggenheim',
#   'Gregory Poirier, Theresa Rebeck',
#   5.9,
#   '1h 30min',
#   nan],
#  ['tt0177195',
#   'Clinton Smith',
#   "Clinton Smith, Peter Buckmaster, Anthony O'Connor",
#   4.1,
#   '1h 37min',
#   'This edgy Australian film stars an ensemble cast headed up by pop superstar Kylie Minogue, David Field, and Simon Lyndon. Various characters interact under strange circumstances, calling to mind movies such as GO and PULP FICTION.'],
#  ['tt0177971',
#   'Wolfgang Petersen',
#   'Sebastian Junger, William D. Wittliff',
#   6.5,
#   '2h 10min',
#   nan],
#  ['tt0177888',
#   'Seth Zvi Rosenfeld',
#   'Seth Zvi Rosenfeld',
#   5.9,
#   '1h 39min',
#   "Seymour's happy New York existence comes to a tragic end after he witnesses the murder of his mother, a renowned civil rights activist. When he finds a firearm in the home of his best friend, he embarks on a deranged quest for revenge."],
#  ['tt0179137',
#   'Silvio Caiozzi',
#   'Silvio Caiozzi, José Donoso',
#   7.1,
#   '2h 20min',
#   'A lonely man becomes increasingly obsessed with the beautiful teenager he used to help care for his grandmother.'],
#  ['tt0177068',
#   'Laurence Fishburne',
#   'Laurence Fishburne',
#   5.2,
#   '1h 47min',
#   'Street hustler Mike cooks up a drug rip-off with his estranged half-brother Torch. Simple robbery turns fatal bloodbath, so they hide out in a claustrophobic rat hole waiting for Mike\'s buddy Tony, who\'s "out of the life," or so he says.'],
#  ['tt0178050',
#   'Adam Collis',
#   'Randall Jahnson, Russell De, Grazier',
#   5.6,
#   '1h 30min',
#   'A comedy that takes place over twenty-four hours on the Sunset Strip, in 1972.'],
#  ['tt0179473',
#   'Dwight Yoakam',
#   'Dwight Yoakam, Dennis Hackin, Otto Felix',
#   4.1,
#   '2h 11min',
#   'A U.S. Marshal tracks a destructive clan of outlaws, while a government man claims that the Marshal is actually a ghost of his deceased self.'],
#  ['tt0179861',
#   'David Giancola',
#   'David Giancola',
#   3.6,
#   '1h 30min',
#   "At the the Killington ski resort something has gone awry. Evil terrorists led by the sinister Greig have taken the resort hostage with a stolen nuclear device. It's up to Ski Patrol bum Matt Foster to save the day... and his fiancé."],
#  ['tt0179443',
#   'Edward Thomas',
#   'James Hawes',
#   3.5,
#   '1h 31min',
#   "Pete in London inherits a company. The ambitious accountant makes a deal with a Russian mafia boss. The Russian wants hard currency and grand-kids but kills his daughter's lovers. His daughter needs an Englishman like Sir Francis Drake."],
#  ['tt0180093',
#   'Darren Aronofsky',
#   'Hubert Selby Jr.Darren Aronofsky',
#   8.3,
#   '1h 42min',
#   nan],
#  ['tt0180073', 'Philip Kaufman', 'Doug Wright', 7.2, '2h 4min', nan],
#  ['tt0179653',
#   'Nick Efteriades',
#   'Nick Efteriades',
#   7.1,
#   '1h 43min',
#   'In Queens, NY, aka "Little Athens," a blue-collar Greek-American family struggle to hold on to the American Dream. Follow the journey of 28-year-old Alex and his desire to escape his urban hometown to pursue an off-beat dream.'],
#  ['tt0181311',
#   'Mary Mc, Guckian',
#   'John Lynch, Mary Mc, Guckian',
#   5.6,
#   '1h 42min',
#   nan],
#  ['tt0181819',
#   'Richard Hobert',
#   'Richard Hobert',
#   5.7,
#   '1h 54min',
#   'Mikael turns 50 and celebrates big time, inviting all his friends to a gigantic party. He has a secret he intends to announce during the party.'],
#  ['tt0180837',
#   'Bruno Barreto',
#   "Alexandre Machado, Sérgio Sant'Anna, Fernanda Young",
#   6.3,
#   '1h 35min',
#   'A separated attorney in Rio sees an English teaching American widow and tries to woo her.'],
#  ['tt0181865',
#   'Steven Soderbergh',
#   'Simon Moore, Stephen Gaghan',
#   7.6,
#   '2h 27min',
#   nan],
#  ['tt0181945', 'John D. Hancock', 'Dorothy Tristan', 5.5, '1h 46min', nan],
#  ['tt0183056',
#   'Arnaud Desplechin',
#   'Arnaud Desplechin, Emmanuel Bourdieu, Arthur Symons',
#   6.8,
#   '2h 37min',
#   'A Jewish girl in nineteenth century London, dreams of becoming a stage actress.'],
#  ['tt0183280',
#   'John Putch',
#   'James Morley IIIKeoni Waxman',
#   3.3,
#   '1h 30min',
#   "When a tsunami created by a nuclear explosion capsizes a cruise ship, a special agent must help the surviving passengers reach the surface when it becomes apparent that there's a group of terrorists on board."],
#  ['tt0183639',
#   'C. Grant Mitchell',
#   'David A. Goodman, Daniel Riordan, Robert Louis Stevenson',
#   4.5,
#   '1h 34min',
#   'The story of Frank Cassilis and Northmour as both seemingly try to protect the Huddlestone family against mexican separatists while each has their own purposes and agenda.'],
#  ['tt0183659',
#   'Ed Harris',
#   'Steven Naifeh, Gregory White Smith, Barbara Turner',
#   7.0,
#   '2h 2min',
#   nan],
#  ['tt0180683',
#   'Matthew Miele',
#   'Chris Fetchko, Matthew Miele',
#   5.9,
#   '1h 32min',
#   'A homeless man takes a newly homeless man under his wing and teaches him how to survive on the streets.'],
#  ['tt0181536', 'Gus Van Sant', 'Mike Rich', 7.3, '2h 16min', nan],
#  ['tt0183550',
#   'Mark Lamprell',
#   'Mark Lamprell',
#   6.4,
#   '1h 35min',
#   'When a meddlesome mother enrolls in university with her son, old and new worlds collide with awesome consequences.'],
#  ['tt0183423',
#   'Kennedy Goldsby',
#   'Kennedy Goldsby',
#   3.8,
#   '1h 29min',
#   "Four friends all going a painful breakup, know too much about each other, and the hostility they've been expressing gets turned toward each other."],
#  ['tt0182508',
#   'Jon Shear',
#   'Daniel Reitz, Jon Shear',
#   6.8,
#   '1h 43min',
#   'A series of urban legends take place around the life of a troubled man who is searching New York City for a mysterious stranger.'],
#  ['tt0181875', 'Cameron Crowe', 'Cameron Crowe', 7.9, '2h 2min', nan],
#  ['tt0181984', 'Ben Younger', 'Ben Younger', 7.0, '2h', nan],
#  ['tt0183808',
#   'Oz Scott',
#   'William Rehor',
#   4.9,
#   '1h 38min',
#   "A con-artist hires two low-lifes to cover him during a deal, ending with three criminals, two dueling pistols, and one night they'll never forget."],
#  ['tt0184056',
#   'Rémi Lange',
#   'Rémi Lange, Antoine Parlebas',
#   7.3,
#   '1h 25min',
#   'Antoine and Rémi have been living together for over three years. Rémi films their life using a Super 8 camera.'],
#  ['tt0183946',
#   'Matthias X. Oberg',
#   'Tim Dabringhaus, Matthias X. Oberg',
#   5.5,
#   '1h 31min',
#   'Black comedy feature about a young undertaker, starting his own firm in a seaside resort.'],
#  ['tt0184858', 'John Frankenheimer', 'Ehren Kruger', 5.8, '1h 44min', nan],
#  ['tt0185215',
#   'Eric Barbier',
#   'Eric Barbier',
#   6.3,
#   '1h 25min',
#   "After having been in jail, Manuel becomes a bullfighter following dangerously his father's steps."],
#  ['tt0186221',
#   'Karl W. Lohninger',
#   'Karl W. Lohninger',
#   7.8,
#   '1h 33min',
#   'A young couple faces its darker sides when the prospective buyers of their house offer more than what was asked for.'],
#  ['tt0186183',
#   'Anthony Waller',
#   'Simon Burke, William Davies',
#   6.1,
#   '1h 48min',
#   nan],
#  ['tt0187880',
#   'Mika Kaurismäki',
#   'Paul Charles Bailly, Mika Kaurismäki',
#   5.7,
#   '1h 30min',
#   'The mechanic Jack tries to get rid of his criminal background.'],
#  ['tt0186151', 'Gregory Hoblit', 'Toby Emmerich', 7.4, '1h 58min', nan],
#  ['tt0187393', 'Roland Emmerich', 'Robert Rodat', 7.2, '2h 45min', nan],
#  ['tt0186975',
#   'Kris Isacsson',
#   'Kris Isacsson',
#   5.0,
#   '1h 31min',
#   'College students Al and Imogen meet and fall in love, but fear of commitment causes them to go their separate ways.'],
#  ['tt0185014',
#   'Curtis Hanson',
#   'Michael Chabon, Steve Kloves',
#   7.2,
#   '1h 47min',
#   nan],
#  ['tt0187474',
#   'Patricia Mazuy',
#   'Yves Dangerfield, Philippe Lauro-Baranes, Patricia Mazuy',
#   6.0,
#   '1h 59min',
#   "Madame de Maintenon rises from humble beginnings to become a courtesan to the royal court and eventually marries King Louis XIV. With the king's indulgence, Maintenon opens a special school for girls."],
#  ['tt0186719',
#   'Catherine Jelski',
#   'Wolfgang Bauer, Catherine Jelski',
#   4.1,
#   '1h 27min',
#   "Charlie, his sexy girlfriend, and his moronic best friend drink, drug, and self-destruct over the course of one day at the home of Charlie's father in Los Angeles."],
#  ['tt0186549',
#   'Linda Yellen',
#   'Linda Yellen, Michael Leeds, Gisela Bernice',
#   5.4,
#   '1h 46min',
#   'In addition to declaring that Katharine\'s (Lynn Redgrave) head and heart line are hopelessly fused into one "simian line", eccentric palm reader/fortune-teller Arnita (Tyne Daly) makes a dire prediction: By the end of the year, one of the couples present at a Halloween party will have broken up. But will it be Katharine and her much-younger boyfriend Rick (Harry Conni... Leer todo'],
#  ['tt0186894', 'Don Roos', 'Don Roos', 5.8, '1h 46min', nan],
#  ['tt0186454',
#   'Art Camacho',
#   'David De, Falco',
#   3.7,
#   '1h 40min',
#   "A Hollywood talent agent's girlfriend thrusts him into a world of strip clubs, drugs and deadly motorcycle gangs."],
#  ['tt0187847',
#   'Charlie Ahearn',
#   'Charlie Ahearn',
#   6.5,
#   '1h 39min',
#   "A young novelist with a bad case of writer's block clears her mind by answering an ad placed by a man who is driving cross-country and needs a partner. Along the way, she ends up with more writing material than she ever bargained for."],
#  ['tt0188160', 'Carlos Avila', 'Phil Berger', 6.1, '1h 58min', nan],
#  ['tt0188189',
#   'S. Leo Chiang',
#   'S. Leo Chiang',
#   6.6,
#   '15min',
#   "The Kid has no money, no place to live and nowhere to go. He's done more than he cares to admit just to survive on the streets.The Man has lost the one he loved. He is losing his eyesight. He's selling all his possessions so nothing will be left to lose. Both are trapped, each alone until Fate brings them together one windy autumn night."],
#  ['tt0188135',
#   'Auli Mantila',
#   'Auli Mantila, Anja Snellman',
#   5.5,
#   '1h 35min',
#   'When her sister is mugged and raped, Oili, a young female forensic dentist, meets a group of abused women who have taken matters to their own hands to make the living in fear and just letting it happen stop.'],
#  ['tt0188518',
#   'Gavin Millar',
#   'Iain Banks, Bryan Elsley',
#   5.8,
#   '1h 39min',
#   'Cameron Colley is a young scottish journalist, with an interest in exposing the wrongs committed by the rich and powerful. Life is comfortable enough but uneventful, until someone starts murdering the people in his articles.'],
#  ['tt0188613',
#   'Guylaine Dionne',
#   'Guylaine Dionne',
#   6.3,
#   '1h 21min',
#   'Three generations of women in a French family come to know each other better as they road trip for a photography assignment.'],
#  ['tt0188490',
#   'Will Conroy',
#   nan,
#   6.6,
#   '1h 32min',
#   "A young man is forced to choose between his fianceé and his family's hotel."],
#  ['tt0188688',
#   'Mike Sedan',
#   'Helen Haxton',
#   4.6,
#   '1h 18min',
#   "Donna is unfulfilled. In an unsatisfying marriage, she finds herself fantasizing about her sultry friends' lovers. But for her, fantasy and forbidden desires are about to be reawakened. Each morning, she will find herself in the arms of a new lover, while her sexy friends seduce her husband, Tom in more ways than one. The art of seduction is animalistic. In a world ob... Leer todo"],
#  ['tt0189509',
#   'Ruy Guerra',
#   'Chico Buarque, Janaina Diniz Guerra, Ruy Guerra',
#   5.4,
#   '1h 35min',
#   'The journey of a middle-class amateur.'],
#  ['tt0190052',
#   'Kelley Cauthen',
#   'Sahara Riley',
#   4.2,
#   '1h 34min',
#   'A beautiful woman has a sexual fantasy that she passes on. Then she is visited by a supernatural being, and things start to get more interesting.'],
#  ['tt0190994',
#   'Randy Bradshaw',
#   'Ian Adams',
#   4.6,
#   '1h 37min',
#   'A serial murderer of teenage girls is loose, and working the case are a possibly corrupt detective Lou Miles a probably corrupt chief inspector Brodsky and his "favorite snitch." Dark personal histories and current politics mix to get the ambitious DA and her investigator involved.'],
#  ['tt0190524',
#   'Vic Sarin',
#   'Alan B. Mc, Elroy, Paul Lalonde, Joe Goodman',
#   4.3,
#   '1h 40min',
#   nan],
#  ['tt0189998', 'E. Elias Merhige', 'Steven Katz', 6.9, '1h 32min', nan],
#  ['tt0190332',
#   'Ang Lee',
#   'Hui-Ling Wang, James Schamus, Kuo Jung Tsai',
#   7.9,
#   '2h',
#   nan],
#  ['tt0190861',
#   'Roland Joffé',
#   'Jeanne Labrune, Tom Stoppard',
#   6.6,
#   '1h 43min',
#   nan],
#  ['tt0191754', 'Betty Thomas', 'Susannah Grant', 6.1, '1h 43min', nan],
#  ['tt0192614', 'Rob Cohen', 'John Pogue', 5.6, '1h 46min', nan],
#  ['tt0190865',
#   'Martin Campbell',
#   'Robert King, Terry Hayes',
#   5.9,
#   '2h 4min',
#   nan],
#  ['tt0192346',
#   'Predrag Velinovic',
#   'Predrag Perisic',
#   6.7,
#   '2h 2min',
#   'Actor who used to be a celebrity once upon a time, when he played in number of films and theatre shows, lives his elderly days monotonously... Up until he meets a girl wanting to become an actress. In their encounters actor revives his love affairs from his young age...'],
#  ['tt0189960',
#   'Paulo Rocha',
#   'Raquel Freire, Regina Guimarães, Paulo Rocha',
#   5.6,
#   '1h 58min',
#   'In Lisbon, during the feasts of St. Anthony, the cross breeders of politicians in black shirts and transvestites all dressed in pink. An exuberant allegory of freedom against dictatorship.'],
#  ['tt0192295',
#   'Joseph Vilsmaier',
#   'Christian Pfannenschmidt',
#   5.7,
#   '2h 12min',
#   'The movie follows the life and personality of the famous actress Marlene Dietrich.'],
#  ['tt0190736',
#   'Matt Palmieri',
#   'Matt Palmieri',
#   4.2,
#   '1h 29min',
#   'A young man tries running from his past by hiding from his two violent brothers, only to have them track and harass him and his friends.'],
#  ['tt0191037',
#   'Rob Walker',
#   'David Logan',
#   5.6,
#   '1h 35min',
#   "Conman Leo Garfield is in hot water after accepting a contract to murder businessman Julius Harvey's alleged wife, Gloria. Leo's wife Lily brings trouble too when her old flame Elmo pops up again, years after she abandoned him mid-heist."],
#  ['tt0191636',
#   'Patrice Leconte',
#   'Claude Faraldo, Patrice Leconte',
#   7.1,
#   '1h 52min',
#   'In a small French colony, a drunken man kills someone. While a guillotine is being shipped in, he changes, becoming a good and popular man.'],
#  ['tt0192719',
#   'Bruce Pittman',
#   'Ivan Kane, John Schafer, Leopold St-Pierre',
#   4.7,
#   '1h 30min',
#   'A businessman becomes the target for a ruthless criminal who mistakes him for the thief who stole his drug money.'],
#  ['tt0190346',
#   'Frédéric Garson',
#   'Luc Besson, Jessica Kaplan',
#   5.7,
#   '1h 29min',
#   'A mute female dancer who wows audiences in club competitions but can\'t get Broadway jobs because of her handicap, develops a "voice" when a young scientist invents a device that allows her to make music via her dance movements.'],
#  ['tt0192949',
#   'Denys Arcand',
#   'Denys Arcand, Jacob Potashnik',
#   5.7,
#   '1h 40min',
#   'A young girl is plucked from small-town obscurity and thrust into the spotlight of the glamorous world of super-models.'],
#  ['tt0191352',
#   'José Álvaro Morais',
#   'José Álvaro Morais, Jeanne Waltz',
#   6.2,
#   '2h 4min',
#   'Dirección'],
#  ['tt0191782', 'Trac Vu', 'Trac Vu', 7.4, '18min', 'Dirección'],
#  ['tt0191865', 'Luigi Magni', 'Luigi Magni', 6.2, '1h 40min', 'Dirección'],
#  ['tt0192678',
#   'Miguel Littin',
#   'Francisco Coloane, Tonino Guerra, Miguel Littin',
#   5.3,
#   '1h 48min',
#   "The chronicles of the Romanian engineer Julius Popper, a nationalized Argentine and one of the principle actors in the genocide of the Selk'nam, one of the indigenous peoples who inhabited the Tierra del Fuego Archipelago."],
#  ['tt0193741',
#   'Markku Pölönen',
#   'Esko Janhunen, Heikki Metsämäki, Markku Pölönen',
#   5.9,
#   '1h 43min',
#   'The life of Rauli "Badding" Somerjoki, a Finnish singer.'],
#  ['tt0193854', 'Michael Corrente', "Denis O'Neill", 6.2, '1h 54min', nan],
#  ['tt0194027',
#   'Lauri Törhönen',
#   'Lauri Törhönen, Laila Hietamies, Pekka Parikka',
#   5.5,
#   '1h 43min',
#   'Summer 1944 in Finnish Karelia; after a long lull, the Soviet army launches an overwhelming offensive that throws everything into disarray. Martta has barely time to marry Aarne before she is evacuated with relatives Hilkka who has just given birth to a son Helmi Elisa, the children, and their grandmother. In the confusion of the retreat, the women try to hold togethe... Leer todo'],
#  ['tt0194319',
#   'Grant Barbeito',
#   'Grant Barbeito',
#   6.2,
#   '6min',
#   'A man prepares his suicide up to the point of perfection.'],
#  ['tt0194218',
#   'Henry Bromell',
#   'Henry Bromell',
#   6.7,
#   '1h 28min',
#   "Alex, a hit man, tries to get out of the family business, but his father won't let him do so. While seeking the help of a therapist, he meets a sexually charged 23-year-old woman with whom he falls in love."],
#  ['tt0195001',
#   'Lars Becker',
#   'Feridun Zaimoglu, Bernhard Wutka, Lars Becker',
#   6.7,
#   '1h 26min',
#   'Dirección'],
#  ['tt0195860',
#   'Agneta Fagerström-Olsson',
#   'Peter Birro, Agneta Fagerström-Olsson',
#   5.4,
#   '1h 50min',
#   '"Plutten" is a former European champion in boxing who tours in northern Sweden, Finland, Norway and Russia as a country musician with his manager "Råttan". "Plutten\'s" big problem is handling the fact that his career is finished and that he has got to start on something completely new.'],
#  ['tt0195857',
#   'Elaine Proctor',
#   'Elaine Proctor',
#   5.2,
#   '1h 29min',
#   'While on a hunt for elephant poachers in Namibia, a white female conservationist and a black lawyer fall for each other, despite the condemnation by the local community.'],
#  ['tt0194852',
#   'Javier Torre',
#   'Isabel de Estrada, Javier Torre',
#   6.8,
#   '1h 32min',
#   'Estela Canto y Jorge Luis Borges se conocieron en 1944. Estela era mujer culta, inteligente, bella e inquietante. Trabajaba como locutora de radio, traducía textos de inglés y quería ser escritora. Borges era un hombre tímido, apegado a su madre, conservador, empleado en un modesta Biblioteca pública. Todavía era un desconocido para el gran público. Comenzaron una rel... Leer todo'],
#  ['tt0195352',
#   'Dana Nechushtan',
#   'Dana Nechushtan, Paul Ruven, Karst Woudstra',
#   6.1,
#   '1h 35min',
#   'A drifter, the doctor who has fallen for him and a third man who has recently lost his father are involved in a fiery auto crash.'],
#  ['tt0196223',
#   'Lyndon Chubbuck',
#   'Larry Brand',
#   5.3,
#   '1h 35min',
#   "A detective falls for the man she's supposed to be investigating; dire complications follow."],
#  ['tt0195944',
#   'Serge Rodnunsky',
#   'Paul Tarantino',
#   4.2,
#   '1h 34min',
#   'A reporter risks his life to get to the bottom of a stack of lies, corruption and murder surrounding the opening of a local power plant.'],
#  ['tt0195685', 'Steven Soderbergh', 'Susannah Grant', 7.4, '2h 11min', nan],
#  ['tt0195778',
#   'Mark Piznarski',
#   'Michael Seitzman',
#   5.2,
#   '1h 36min',
#   'A rich college kid is taught a lesson after a joy ride ends up destroying a country restaurant.'],
#  ['tt0195631',
#   'Peter Liapis',
#   'Peter Liapis, Richard Dana Smith',
#   4.9,
#   '1h 30min',
#   nan],
#  ['tt0195979', 'Pedro Caldas', 'Jorge Silva Melo', 5.0, '7min', 'Dirección'],
#  ['tt0196219',
#   'Albert Pyun',
#   'Albert Pyun',
#   2.2,
#   '1h 20min',
#   'A high-level government hit squad is sent into the streets in order to complete a deadly mission.'],
#  ['tt0197311',
#   'John Berry',
#   'Athol Fugard, John Berry',
#   5.7,
#   '1h 30min',
#   'Intense love and hate bring a man and woman through personal tragedy.'],
#  ['tt0197072',
#   'Jean Pellerin',
#   'Phillip J. Roth, Jim Christopher',
#   3.8,
#   '1h 27min',
#   'A car ferry carrying a valuable artifact is sunk by a group of international thieves.'],
#  ['tt0197384', 'Rob Schmidt', 'Larry Gross', 5.8, '1h 38min', nan],
#  ['tt0197402',
#   'Pål Jackman',
#   'Erlend Loe',
#   6.6,
#   '1h 44min',
#   'Daniel Jul is a 28-year-old psychiatrist still living with his mom. He and his friend Ronny have one thing in common: they like searching for metallic objects in the ground. One day they find a jewel with the name "Janne" imprinted. This is the beginning of something big for Daniel. His life will never be the same. He\'s about to discover a lot of hidden secrets about ... Leer todo'],
#  ['tt0196723',
#   'John Kaye',
#   'John Kaye',
#   5.6,
#   '1h 39min',
#   'A schizophrenic romantic tracks down her college sweetheart to help her find their son she gave up for adoption sixteen years ago to the dismay of his new wife.'],
#  ['tt0197644',
#   'C.B. Harding',
#   'Giorgio Serafini',
#   4.5,
#   '1h 39min',
#   "A beautiful mysterious woman enters the life of a sexy photographer, her friend and friend's boyfriend. They spend a couple of days together in a huge beach house and their inhibitions fade."],
#  ['tt0197646',
#   'Mark Gibson',
#   'Mark Gibson',
#   4.7,
#   '1h 33min',
#   'Lionel "Ex" Exley is a golf pro who returns to his hometown of New Orleans, where he befriends lawyer W. Firmin Carter. When Carter suddenly goes missing, however, the party\'s over for Ex, as he\'s the prime suspect.'],
#  ['tt0197740',
#   'Roberto Petrocchi',
#   'Paola Capriolo, Roberto Petrocchi, Riccardo de Luca',
#   6.6,
#   '1h 32min',
#   "Roberto Petrocchi directs this period drama set in the late 1800s. Capt. Eugenio (Arnaud Arbessier) arrives in a remote castle to take charge of a unit guarding a nameless prisoner. No one knows much about the inmate as he is held in a forlorn tower. When the captain's wife Adele (Margherita Buy) tries to shake her melancholia by playing the piano, she finds -- much t... Leer todo"],
#  ['tt0196708',
#   'John Luessenhop',
#   'Preston A. Whitmore II',
#   6.2,
#   '1h 45min',
#   'Avery (Jones) returns to college as a competitive swimmer after getting his life back on track. But his life takes another unexpected turn when he and his two friends (Bonds, Casseus) are wrongly accused of murder and end up in prison.'],
#  ['tt0197096',
#   'Gurinder Chadha',
#   'Gurinder Chadha, Paul Mayeda Berges',
#   6.8,
#   '1h 49min',
#   'Four families in LA of different ethnicity (Latino, Asian/Vietnamese, African and Jewish) gather together for Thanksgiving dinner.'],
#  ['tt0197753',
#   'Jennifer Warren',
#   'Brett Lewis',
#   5.6,
#   '1h 30min',
#   'Assigned to the mysterious kidnapping of a wealthy family man, a police detective must share his investigation with his ex-wife, an FBI agent. As tensions mount between them, Detective Reardon suddenly becomes the prime suspect.'],
#  ['tt0197299',
#   'Jenõ Hódi',
#   'Christopher Pearce, Jenõ Hódi, Ian Patrick Williams',
#   3.6,
#   '1h 22min',
#   'Renegade CIA agent Rick Halsey assembles a team of special forces operatives to rescue a Russian nuclear scientist held in a fortified mental institution behind enemy lines.'],
#  ['tt0197104',
#   'Jack Williams',
#   'Ashe Starr',
#   2.6,
#   'R',
#   'Rock singer Erika is murdered with her cop boyfriend on the eve of Halloween. Then exactly one year later she is resurrected by a mysterious crow to exact vengeance on her attackers.'],
#  ['tt0198021',
#   'Matt Williams',
#   'Lowell Ganz, Babaloo Mandel, Billie Letts',
#   6.7,
#   '2h',
#   nan],
#  ['tt0198320',
#   'Robert Martin Carroll',
#   'Dalene Young',
#   6.1,
#   '2000',
#   'Free spirit Lee Ann plans to sell her baby to pay her rent, much to the dismay of her roommate.'],
#  ['tt0198284',
#   'Cameron Thor',
#   'Thomas M. Kostigen',
#   4.5,
#   '1h 36min',
#   '4 LA women, 3 married, go to a Palm Springs resort together for a weekend of flirting etc. Consequences?'],
#  ['tt0198893',
#   'Mike Sedan',
#   'Helen Haxton',
#   4.1,
#   '1h 35min',
#   "Struggling publisher's agent, in a bad live-in relationship, recruits a romance novelist whose bestsellers document her affair with the agent, and betrayal. She refuses the deal, just to spite him. But an old friend shows up to rescue him from both traps."],
# ...
#   'Lynn Hershman Leeson',
#   'Lynn Hershman Leeson',
#   5.3,
#   '1h 25min',
#   'Tilda Swinton plays four roles in this award-winning film about Rosetta Stone and her three Self-Replicating Automatons, which she cloned from her own D.N.A.'],
#  ['tt0270991',
#   'Steve Akahoshi',
#   'Joel Eisenberg, Brandon Borbeck',
#   3.3,
#   '1h 30min',
#   'A tale of the underground gothic subculture as seen through the eyes of Fatal, a young female vampire. As a heroin addict, she embraced this dark lifestyle, she now knows she must break free from their depraved world.'],
#  ['tt0272736',
#   'Kunal Kohli',
#   'Kunal Kohli',
#   5.1,
#   '2h 29min',
#   'Meet Raj, Pooja and Tina - 3 best friends thrown into a situation that time, letters, love and separation have created for them.'],
#  ['tt0273069',
#   'Nicole Garcia',
#   'Frédéric Bélier-Garcia, Emmanuel Carrère, Jacques Fieschi',
#   6.8,
#   '2h 9min',
#   "When a man murders his wife, children and parents, the ensuing investigation reveals that he's been living a lie for almost 20 years."],
#  ['tt0271045',
#   'Mandel Holland',
#   'Mandel Holland',
#   5.2,
#   '1h 34min',
#   "In Harlem, Martin Blaze, a writer for Vibe, thinks he's a loser since his fiancée cheated on him. The evening after his father's funeral, he meets the lovely Paula, runs into her the next day, but is sure she'll never look twice at him. His older brother Junnie offers to coach him on how to be a player, promising Martin that within two weeks, she'll be his. The lesson... Leer todo"],
#  ['tt0273453',
#   'Kasia Adamik',
#   'Heather Morgan',
#   4.9,
#   '1h 34min',
#   'A comedy about misfits in which a veterinarian becomes involved with a client, whose wife has begun acting like a dog. Darla is the vet while Peter is the frazzled husband, whose marriage is going to the dogs.'],
#  ['tt0271000',
#   'Susan Taslimi',
#   'Susan Taslimi',
#   5.4,
#   '1h 40min',
#   "Minoo returns to her family in Sweden to attend her sister Gita's wedding. Her mother and father believe that she has disgraced the family having worked as a stripper."],
#  ['tt0270288',
#   'George Clooney',
#   'Chuck Barris, Charlie Kaufman',
#   7.0,
#   '1h 53min',
#   nan],
#  ['tt0271219',
#   'Gary Winick',
#   'Heather Mc, Gowan, Niels Mueller, Gary Winick',
#   6.2,
#   '1h 18min',
#   'Coming-of-age story about a suave 15-year-old prep school student who falls in love with his stepmother. When her best friend responds to his advances, he suddenly finds himself in way over his head.'],
#  ['tt0271018',
#   'David Michael Latt',
#   'David Michael Latt, Kim Little',
#   3.8,
#   '1h 24min',
#   "Jane White's only ambition is to appear on a popular talk show."],
#  ['tt0271537',
#   'Michael Almereyda',
#   'Michael Almereyda',
#   5.3,
#   '1h 29min',
#   "When an unhappy young woman disappears, her worried sister desperately searches the internet for a clue to her missing sibling's whereabouts."],
#  ['tt0272207', 'Joe Carnahan', 'Joe Carnahan', 7.1, '1h 45min', nan],
#  ['tt0271798',
#   'Billy Hayes',
#   'Richard Crowe, Richard Zajdlic, Billy Hayes',
#   5.4,
#   '1h 46min',
#   nan],
#  ['tt0271885',
#   'David S. Goyer',
#   'Landon J. Napoleon, David S. Goyer',
#   5.9,
#   '1h 41min',
#   'An autistic 15-year-old boy steals money from his boss to provide rent for his abusive father, who uses the money to repay a loan shark.'],
#  ['tt0271582',
#   'Jon Purdy',
#   'Joseph F. Girzone, Brad Mirman, Keith Giglio',
#   6.6,
#   '1h 31min',
#   '"Joshua" tells the story of a possible second coming of Christ to a small U.S. town.'],
#  ['tt0272338',
#   'Paul Thomas Anderson',
#   'Paul Thomas Anderson',
#   7.3,
#   '1h 35min',
#   nan],
#  ['tt0272557',
#   'John Murlowski',
#   'Russell V. Manzatt',
#   4.1,
#   '1h 35min',
#   'A pair of criminals infect the president of the United States with a deadly virus. His only hope is to give in to their demands, but he refuses to cooperate with terrorists. Now it is up to Dr. Diane Landis to save his life.'],
#  ['tt0273457',
#   'John Quinn',
#   'Barbara Fixx',
#   4.5,
#   '1h 38min',
#   'A detective and his girlfriend, investigate the murder of a well-known model. They discover a videotape on which she can be seen in bondage games - diving them further into her double life.'],
#  ['tt0273435', 'Atom Egoyan', 'Atom Egoyan', 6.3, '1h 55min', nan],
#  ['tt0274309',
#   'Michael Winterbottom',
#   'Frank Cottrell Boyce',
#   7.3,
#   '1h 57min',
#   nan],
#  ['tt0273982',
#   'Mars Callahan',
#   'Mars Callahan, Chris Corso',
#   6.8,
#   '1h 39min',
#   nan],
#  ['tt0273923', 'Jake Kasdan', 'Mike White', 6.2, '1h 22min', nan],
#  ['tt0274471',
#   'Jean-Paul Civeyrac',
#   'Jean-Paul Civeyrac, Jean de Tinan',
#   6.4,
#   '1h 20min',
#   'In Paris, young Raoul is a writer who wishes to find love. He first falls for Jeanne and spends the bulk of his time lounging around with his circle of friends and sleeping around.'],
#  ['tt0274424',
#   'Ildikó Szabó',
#   'Gergely Fogarasi, Zoltán JancsóIldikó Szabó',
#   6.8,
#   '2h 5min',
#   'A gypsy apothecary-violinist befriends a Hapsburg prince after saving his life during the disastrous Hungarian War of Independence in 1849.'],
#  ['tt0274407',
#   'Franco Zeffirelli',
#   'Franco Zeffirelli, Martin Sherman',
#   6.4,
#   '1h 52min',
#   nan],
#  ['tt0274430',
#   'Simon Rumley',
#   'Simon Rumley',
#   5.6,
#   '1h 19min',
#   'One eventful night at a seedy London nightclub in 1993.'],
#  ['tt0274019',
#   nan,
#   'S.M. Ahale, Shashi, Javed Siddiqui',
#   4.0,
#   '2h 28min',
#   'A villager pretends to be disabled in order to be near an NRI (Non-Resident Indian).'],
#  ['tt0274558',
#   'Stephen Daldry',
#   'Michael Cunningham, David Hare',
#   7.5,
#   '1h 50min',
#   nan],
#  ['tt0274643', 'Tony Shalhoub', 'Lynne Adams', 6.0, '1h 36min', nan],
#  ['tt0274812',
#   'Steven Shainberg',
#   'Erin Cressida Wilson, Mary Gaitskill, Steven Shainberg',
#   6.9,
#   '1h 47min',
#   nan],
#  ['tt0274428', 'Elia Suleiman', 'Elia Suleiman', 6.6, '1h 32min', nan],
#  ['tt0274639',
#   'Brian Flemming',
#   'Brian Flemming',
#   6.1,
#   '1h 22min',
#   'A mockumentary examining the December 2nd, 1999 assassination of Microsoft CEO Bill Gates in Los Angeles, and the group of key players seeking to unravel the mystery of his alleged assassin as well as the circumstances surrounding his death.'],
#  ['tt0274711',
#   'Daniel Algrant',
#   'Jon Robin Baitz',
#   5.4,
#   '1h 40min',
#   'A New York press agent must scramble when his major client becomes embroiled in a huge scandal.'],
#  ['tt0274847',
#   'Leopoldo Laborde',
#   'Leopoldo Laborde',
#   5.3,
#   '1h 37min',
#   'This is a shocking film that deals with a 15-year-old boy who rents his body to men in order to pay for his drug abuses. Fran, tired of being termed a homosexual by others, confides in his best friend and dealer David who advises him to visit Perla, a prostitute. Fran later encounters a fair-haired girl, Angelica, and is initially attracted towards her, but soon the o... Leer todo'],
#  ['tt0275295',
#   "Pat O'Neill",
#   nan,
#   7.8,
#   '1h 13min',
#   'The film is an "intersection of fact and hallucination" set inside the decaying walls of the old Ambassador Hotel and the famed Cocoanut Grove restaurant which was home to the 1st Academy Awards.'],
#  ['tt0275022', 'Tamra Davis', 'Shonda Rhimes', 3.7, '1h 33min', nan],
#  ['tt0275072',
#   'Tomasz Wiszniewski',
#   'Robert Brutter, Tomasz Wiszniewski',
#   6.7,
#   '1h 35min',
#   'Sharkey, part of the sinister world of child trade, picks up Vlado, an orphan of war, dreaming of freedom and a better life. They embark upon a strange and enlightening journey through war torn Bosnia. As they struggle to get out of the country and fight to stay alive, they find a special love and compassion from which emerges their ultimate moral and spiritual redemp... Leer todo'],
#  ['tt0275275',
#   'Michael Snow',
#   'Michael Snow',
#   6.7,
#   '1h 32min',
#   'A surreal and comic exploration of an office space and the decorations of a living room.'],
#  ['tt0275639',
#   'Patrice Leconte',
#   'Serge Frydman, Patrice Leconte',
#   5.3,
#   '1h 31min',
#   'A handyman in a 1940s Paris brothel tries to help the prostitute he loves with her singing career and romantic life.'],
#  ['tt0275263',
#   'Frank Ciota',
#   'Joseph A. Ciota',
#   8.0,
#   '1h 40min',
#   "An Italian-American travels back to his ancestors' land to coach a colorful team in Italy's fledgling American Football League. A beautiful young girl forces him to face the same decision as his immigrant grandfather had, 70 years earlier."],
#  ['tt0275847',
#   'Dean De, Blois, Chris Sanders',
#   'Chris Sanders, Dean De, Blois',
#   7.3,
#   '1h 25min',
#   nan],
#  ['tt0276140',
#   'Ate de Jong',
#   'Michael Lally, Ate de Jong',
#   4.9,
#   '1h 37min',
#   'Three friends get stuck in fog on the way to a holiday. They tell each other stories and confront each other with hidden secrets...'],
#  ['tt0277789',
#   'Félix Olivier',
#   'Michael Philip Del Rio, Félix Olivier, Richard Schlesinger',
#   6.7,
#   '1h 31min',
#   "15 year old girl leaves foster care and embraces life on New York's mean streets."],
#  ['tt0276751',
#   'Chris Weitz, Paul Weitz',
#   'Nick Hornby, Peter Hedges, Chris Weitz',
#   7.1,
#   '1h 41min',
#   nan],
#  ['tt0277184',
#   'Paul Quinn',
#   'Nick Gillie',
#   6.9,
#   '1h 37min',
#   'The story of young men whose recovery from drug abuse hangs on their self-management of a gritty L.A. rehab center.'],
#  ['tt0277625',
#   'Michel Jetté',
#   'Michel JettéLéo Lévesque',
#   6.2,
#   '1h 52min',
#   "At the age of nineteen, Claude lands himself in a maximum security penitentiary. His strong will and good looks immediately land him in trouble with Tarzan, the leader of a ruthless prison gang. Claud's talents as a fighter squash Tarzan's brutal advances, but at a high price. Now his life is in danger. Zi zi, a rival gang leader, notices Claude's potential and offers... Leer todo"],
#  ['tt0277790',
#   'Christian Mc, Intire',
#   'Michael Johnston',
#   4.2,
#   '1h 34min',
#   'Two teams are in a heated race for the money and the honor that comes with breaking the land speed world record.'],
#  ['tt0277434',
#   'Randall Wallace',
#   'Harold G. Moore, Joseph Lee Galloway, Randall Wallace',
#   7.2,
#   '2h 23min',
#   nan],
#  ['tt0278035',
#   'Glenn Durfort, Colin Teague',
#   'Louis Dempsey, Andrew Howard, Gary Young',
#   5.4,
#   '1h 35min',
#   "Gilly, fresh out of prison, and J, a hustler with a major drug problem, just can't shake their criminal ways."],
#  ['tt0277944',
#   'Bob Misiorowski',
#   'Jace Anderson, Boaz Davidson, Adam Gierasch',
#   3.7,
#   '1h 31min',
#   nan],
#  ['tt0277744', 'Mark Malone', 'Mark Malone', 5.2, '1h 34min', nan],
#  ['tt0278395', 'Michael Vickerman', nan, 5.0, '1h 29min', nan],
#  ['tt0278435', 'Michael Apted', 'Nicholas Kazan', 5.8, '1h 55min', nan],
#  ['tt0278504',
#   'Christopher Nolan',
#   'Hillary Seitz, Nikolaj Frobenius, Erik Skjoldbjærg',
#   7.2,
#   '1h 58min',
#   nan],
#  ['tt0279113', 'Miguel Arteta', 'Mike White', 6.4, '1h 33min', nan],
#  ['tt0279037',
#   'Uwe Boll',
#   'Robert Dean Klein, Uwe Boll',
#   4.4,
#   '1h 27min',
#   'On the last day of school, two bullied teenagers decide to take revenge on their tormentors.'],
#  ['tt0279469',
#   'Alan Swyer',
#   'Alan Swyer, Frank Rossi',
#   4.8,
#   '1h 28min',
#   'Time of Fear is a taut psychological thriller thrusting an FBI agent and a grieving father into the dark world of a demented killer. FBI Agent Cheryl Hammer, arrives in a small California town to catch an elusive killer. Seeing no help forthcoming from the Sheriff, she turns to the only other person who can help her, Jack Barone, a grieving father whose daughter, Lisa... Leer todo'],
#  ['tt0278731', 'David Cronenberg', 'Patrick Mc, Grath', 6.8, '1h 38min', nan],
#  ['tt0278514',
#   'Brenda Keesal',
#   'Brenda Keesal',
#   5.8,
#   '1h 37min',
#   'A black man and a Jewish woman crash into each other and win a dream house in the suburbs. Love-starved neighbours invade their brand-new home, and an all-night party pushes every one of them to a climax of truth, hope and liberation.'],
#  ['tt0279331',
#   'Ron Shelton',
#   'James Ellroy, David Ayer',
#   6.6,
#   '1h 58min',
#   nan],
#  ['tt0278500',
#   'Oliver Parker',
#   'Oscar Wilde, Oliver Parker',
#   6.8,
#   '1h 37min',
#   nan],
#  ['tt0279721',
#   'Damian Chapa',
#   'Damian Chapa, Aaron Pugliese',
#   4.7,
#   '1h 56min',
#   'The Leroy Jenkins Story, following the controversial life of evangelist Leroy Jenkins'],
#  ['tt0279778',
#   'Callie Khouri',
#   'Rebecca Wells, Mark Andrus, Callie Khouri',
#   6.1,
#   '1h 56min',
#   nan],
#  ['tt0279154', 'Fritz Lehner', 'Fritz Lehner', 6.9, '2h 53min', 'Dirección'],
#  ['tt0279074',
#   'Joseph Pierson',
#   'Mike Jones',
#   7.3,
#   '1h 32min',
#   'Set in a dirt-poor neighborhood in the fictional city of San Lovisa, Texas, EvenHand tells the story of two very different cops, working together for the first time. Rob Francis, recently divorced, finds the adjustment from his previous assignment in "Sleepytown" difficult. With his new partner, the volatile Ted Morning, he spends his days breaking up domestic dispute... Leer todo'],
#  ['tt0279725',
#   'Guita Schyfter',
#   'Hugo Hiriart',
#   5.8,
#   '1h 52min',
#   "A revealing view into the lives of Latin American women. The drama follows five women from different walks of life as they converge in Mexico City to review the entries in the Latin American Women's Film Festival."],
#  ['tt0279871',
#   'Éric Heumann',
#   'Éric Heumann, Jacques Lebas, François-Olivier Rousseau',
#   5.5,
#   '1h 30min',
#   'Dirección'],
#  ['tt0279410',
#   'Rachel Feldman',
#   'Rachel Feldman, Cornell Woolrich',
#   5.1,
#   '1h 30min',
#   nan],
#  ['tt0280380', 'Luis Mandoki', 'Greg Iles', 6.1, '1h 46min', nan],
#  ['tt0280477',
#   'Justin Lin',
#   'Ernesto Foronda, Justin Lin, Fabian Marquez',
#   7.0,
#   '1h 41min',
#   'A group of over-achieving East Asian American high school seniors enjoy a power trip when they dip into extracurricular criminal activities.'],
#  ['tt0280438',
#   'Edward Burns',
#   'Edward Burns',
#   5.8,
#   '1h 39min',
#   "Ash Wednesday is set in the Manhattan of the early 1980's and is about a pair of Irish-American brothers (Burns and Wood) who become embroiled in a conflict with the Irish Mob."],
#  ['tt0281924',
#   'Ole Bornedal, Tony Spataro',
#   'Ole Bornedal, Jonas Cornell, Herbjørg Wassmo',
#   6.5,
#   '2h 5min',
#   "Dina grows up in a village at a fjord in 1860s north Norway. As child, she accidentally kills her mom and loses her rich dad's love. She grows up to be a clever, pretty, wild, and strange woman. She marries a rich Frenchman."],
#  ['tt0280874',
#   'Philipp Stölzl',
#   'David Hamblyn, Wolfgang Kohlhaase',
#   6.7,
#   '1h 45min',
#   'Alice is given a parenting exercise at school which changes her understanding of the world in a way she never expected.'],
#  ['tt0280658',
#   'Rajiv Maikhuri',
#   'Harold Crooks, Medrie Mac, Phee, Rajiv Maikhuri',
#   7.5,
#   '24min',
#   "Based on a true story of two 'remarkeble lunatics' trying to find the meaning of the word 'art' while confined in a mental asylum."],
#  ['tt0280760', 'Burr Steers', 'Burr Steers', 6.8, '1h 38min', nan],
#  ['tt0280665', 'Brian De Palma', 'Brian De Palma', 6.2, '1h 54min', nan],
#  ['tt0281322',
#   'Walter Hill',
#   'David Giler, Walter Hill',
#   6.1,
#   '1h 36min',
#   nan],
#  ['tt0280490',
#   'Scott Roberts',
#   'Scott Roberts',
#   6.0,
#   '1h 42min',
#   '3 brothers are in and out of prison in connection with heists planned by their lawyer et al. He gets them out for the heists and "looks after" the money and one\'s wife.'],
#  ['tt0280699',
#   'Robert Schindel, Lukas Stepanik',
#   'Georg Stefan Troller, Robert Schindel, Lukas Stepanik',
#   6.3,
#   '1h 50min',
#   'A holocaust survivor now living as a respected writer in Manhattan is the only person who can identify a suspected Nazi back in his native Austria. When a beautiful reporter eager for a scoop tries to lure him back, Geburtig must decide whether to confront his past.'],
#  ['tt0282613',
#   'Dusty Nelson',
#   'Dusty Nelson',
#   3.5,
#   '1h 31min',
#   "A fire chief (Gunn) is investigating the cause of a string of blazes that threaten to destroy her small town, while at the same time dealing with her teen daughter's rebelliousness."],
#  ['tt0280523',
#   'Delphine Gleize',
#   'Delphine Gleize',
#   6.1,
#   '2h 10min',
#   'After a bull dies in an arena, its remains are transported throughout Belgium, France, and Spain, where various characters cross its path.'],
#  ...]

# %%
df_drama = pd.DataFrame(lista_tuplas)

df
# Out:
#               0                                 1  \
# 0     tt0113092        David Douglas, Tim Douglas
# 1     tt0113092        David Douglas, Tim Douglas
# 2     tt0113086                       Michael New
# 3     tt0116748                     Rakesh Roshan
# 4     tt0115874             Marcos Manhães Marins
# ...         ...                               ...
# 2775  tt0381704                   Dylan Verrechia
# 2776  tt0381849                     James Mangold
# 2777  tt0382036  James Alario, Robin Atkin Downes
# 2778  tt0383064                    Zoltán Kamondi
# 2779  tt0383929                       Samm Styles
#
#                                                       2    3         4  \
# 0                    David Douglas, Christopher Salazar  3.4  1h 40min
# 1                    David Douglas, Christopher Salazar  3.4  1h 40min
# 2                                                   NaN  6.8      2000
# 3           Sachin Bhowmick, Ravi Kapoor, Sagar Sarhadi  3.7        3h
# 4                                 Marcos Manhães Marins  NaN       NaN
# ...                                                 ...  ...       ...
# 2775  Dylan Verrechia, James Lefkowitz, Pablo Tendil...  6.1  1h 19min
# 2776         Halsted Welles, Michael Brandt, Derek Haas  7.6   2h 2min
# 2777                                    Sahag Gureghian  6.5  1h 12min
# 2778       Ádám Bodor, Zoltán Kamondi, Lajos Parti Nagy  5.5   2h 2min
# 2779                                                NaN  6.4  1h 56min
#
#                                                       5
# 0     Earth is in a state of constant war and two co...
# 1     Earth is in a state of constant war and two co...
# 2     Florentino is a young horseman and singer, a f...
# 3     Wealthy Rajiv Sinha and middle-classed Amar Sa...
# 4                                             Dirección
# ...                                                 ...
# 2775  A boy will do anything to become a man and win...
# 2776                                                NaN
# 2777  In this ensemble black comedy, family secrets ...
# 2778  Gabriel Ventuza lives the peaceful life of a h...
# 2779  Inmate activist George Lester Jackson's short ...
#
# [2780 rows x 6 columns]

# %%
df_drama.to_csv('drama_IMDB.csv', index=False)

# %%
df_drama = pd.read_csv('InfoDramaBien3_sin_duplicados.csv')

# %%
df_drama
# Out:
#                0                    1  \
# 0      tt0362209        Jason Rosette
# 1      tt0362822  Christopher Peditto
# 2      tt0362691          Nate Thomas
# 3      tt0368151      Jennifer Harper
# 4      tt0368794          Todd Haynes
# ...          ...                  ...
# 1888  tt10592842    Suridh Das-Hassan
# 1889  tt10603372       Lisa Bierwirth
# 1890  tt10605812         Mauricio Eça
# 1891  tt10607372         Scott Rivers
# 1892  tt10607058             Amy Poux
#
#                                                2    3         4  \
# 0                                  Jason Rosette  7.1  1h 25min
# 1           Jonathan Lethem, Christopher Peditto  4.7  1h 10min
# 2     Danielle Porter, Jeffery Taylor, Deon Reid  4.2  1h 25min
# 3                    Dale Davis, Jennifer Harper  4.9  1h 28min
# 4                     Todd Haynes, Oren Moverman  6.8  2h 15min
# ...                                          ...  ...       ...
# 1888                           Suridh Das-Hassan  NaN       NaN
# 1889                 Hannes Held, Lisa Bierwirth  6.5   2h 5min
# 1890                 Ilana Casoy, Raphael Montes  5.9  1h 25min
# 1891                                Scott Rivers  NaN       NaN
# 1892                                    Amy Poux  NaN       NaN
#
#                                                       5
# 0     Accompanied by her illegal immigrant companion...
# 1     Realism and fantasy collide in Jonathan Lethem...
# 2     The coming of age story about two brothers who...
# 3     Cedric Tinsel (Allen Payne) is a 27-year-old p...
# 4                                                   NaN
# ...                                                 ...
# 1888  Struggling artist Ezra becomes obsessed with t...
# 1889  In Frankfurt's Bahnhofsviertel, two people mee...
# 1890                                                NaN
# 1891  The Horrible Hunters Follows The Life Of 5 Hun...
# 1892                                          Dirección
#
# [1893 rows x 6 columns]

# %%
# Lee los tres archivos CSV en DataFrames
df1 = pd.read_csv('drama_IMDB.csv')
df2 = pd.read_csv('InfoDramaBien3_sin_duplicados.csv')


# Combina los DataFrames en uno solo
df_IMDB_drama = pd.concat([df1, df2], ignore_index=True)

# %%
drama_IMDB_clean= df_IMDB_drama.drop_duplicates()

# %%
drama_IMDB_clean.to_csv('drama_IMDB_clean.csv', index=False)

# %%
len(drama_IMDB_clean)
# Out:
# 4651

# %%
with open ('ComediaWIP.json', 'r') as fichero:
    ComediaWIP= json.load (fichero)

# %%
len(ComediaWIP)
# Out:
# 498

# %%
df_drama = pd.DataFrame(lista_tuplas)
