# %%
import numpy as np
import json
import pandas as pd
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_8024\3038981905.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
columnas_imbd = ['id_film','Direccion', 'Guion','Puntuacion','Duracion','Argumento']

# %%
imdb_accion = pd.read_csv("Archivos_IMDB/accion_IMDB_clean.csv")

# %%
imdb_accion.head()
# Out:
#            0                  1                                           2  \
# 0  tt0485535     Lalji B. Yadav                                  K.K. Gupta
# 1  tt0772175  John Charles Hunt                           John Charles Hunt
# 2  tt0829150         Gary Shore    Matt Sazama, Burk Sharpless, Bram Stoker
# 3  tt0831387     Gareth Edwards  Ishirô Honda, Takeo Murata, Shigeru Kayama
# 4  tt0835775  Tristan Patterson             Timothy Ford, Tristan Patterson
#
#      3         4                                                  5
# 0  5.3  2h 16min                                          Dirección
# 1  5.8  1h 40min  A suburban woman witnesses her husbands murder...
# 2  6.2  1h 32min                                                NaN
# 3  6.4   2h 3min                                                NaN
# 4  4.6  1h 35min  A chronicle of the life of furniture salesman ...

# %%
imdb_accion.columns
# Out:
# Index(['0', '1', '2', '3', '4', '5'], dtype='object')

# %%
imdb_accion2 = imdb_accion.rename(columns={'0':'id_film','1':'Direccion','2':'Guion','3':'Puntuacion_IMDB','4':'Duracion','5':'Argumento'})

# %%
imdb_accion2
# Out:
#          id_film          Direccion  \
# 0      tt0485535     Lalji B. Yadav
# 1      tt0772175  John Charles Hunt
# 2      tt0829150         Gary Shore
# 3      tt0831387     Gareth Edwards
# 4      tt0835775  Tristan Patterson
# ...          ...                ...
# 2903  tt11005524     Mauro Borrelli
# 2904  tt11023732       Venu Udugula
# 2905  tt11116912        Roar Uthaug
# 2906  tt11138512      Robert Eggers
# 2907  tt11151916       John V. Soto
#
#                                            Guion  Puntuacion_IMDB  Duracion  \
# 0                                     K.K. Gupta              5.3  2h 16min
# 1                              John Charles Hunt              5.8  1h 40min
# 2       Matt Sazama, Burk Sharpless, Bram Stoker              6.2  1h 32min
# 3     Ishirô Honda, Takeo Murata, Shigeru Kayama              6.4   2h 3min
# 4                Timothy Ford, Tristan Patterson              4.6  1h 35min
# ...                                          ...              ...       ...
# 2903                                 Sean Wathen              NaN       NaN
# 2904                                Venu Udugula              6.7  2h 31min
# 2905                    Espen Aukan, Roar Uthaug              5.8  1h 41min
# 2906                         Sjón, Robert Eggers              7.0  2h 17min
# 2907  Adam Enslow, Dane Millerd, Andrew Slattery              5.3  1h 28min
#
#                                               Argumento
# 0                                             Dirección
# 1     A suburban woman witnesses her husbands murder...
# 2                                                   NaN
# 3                                                   NaN
# 4     A chronicle of the life of furniture salesman ...
# ...                                                 ...
# 2903  A police detective hunts down the elusive prof...
# 2904  Set against the backdrop of the Naxal movement...
# 2905                                                NaN
# 2906                                                NaN
# 2907                                                NaN
#
# [2908 rows x 6 columns]

# %%
rottem_accion = pd.read_csv("Archivos_ROTTEM/rottem_accion.csv")

# %%
rottem_accion.head()
# Out:
#            0    1
# 0  tt0113092  60%
# 1  tt0116391  60%
# 2  tt0116628  60%
# 3  tt0119273   8%
# 4  tt0120755   8%

# %%
rottem_accion_2 = rottem_accion.rename(columns={'0':'id_film','1':'Puntuacion_Rottem'})

# %%
df_combined = pd.merge(imdb_accion2, rottem_accion_2, left_on='id_film', right_on='id_film', how='inner')

# %%
accion = df_combined[['id_film','Direccion', 'Guion','Puntuacion_IMDB','Puntuacion_Rottem','Duracion','Argumento']]

# %%
accion
# Out:
#          id_film          Direccion  \
# 0      tt0485535     Lalji B. Yadav
# 1      tt0772175  John Charles Hunt
# 2      tt0829150         Gary Shore
# 3      tt0831387     Gareth Edwards
# 4      tt0835775  Tristan Patterson
# ...          ...                ...
# 2672  tt11005524     Mauro Borrelli
# 2673  tt11023732       Venu Udugula
# 2674  tt11116912        Roar Uthaug
# 2675  tt11138512      Robert Eggers
# 2676  tt11151916       John V. Soto
#
#                                            Guion  Puntuacion_IMDB  \
# 0                                     K.K. Gupta              5.3
# 1                              John Charles Hunt              5.8
# 2       Matt Sazama, Burk Sharpless, Bram Stoker              6.2
# 3     Ishirô Honda, Takeo Murata, Shigeru Kayama              6.4
# 4                Timothy Ford, Tristan Patterson              4.6
# ...                                          ...              ...
# 2672                                 Sean Wathen              NaN
# 2673                                Venu Udugula              6.7
# 2674                    Espen Aukan, Roar Uthaug              5.8
# 2675                         Sjón, Robert Eggers              7.0
# 2676  Adam Enslow, Dane Millerd, Andrew Slattery              5.3
#
#      Puntuacion_Rottem  Duracion  \
# 0                  61%  2h 16min
# 1                  61%  1h 40min
# 2                  61%  1h 32min
# 3                  76%   2h 3min
# 4                  76%  1h 35min
# ...                ...       ...
# 2672               91%       NaN
# 2673               91%  2h 31min
# 2674               90%  1h 41min
# 2675               90%  2h 17min
# 2676               80%  1h 28min
#
#                                               Argumento
# 0                                             Dirección
# 1     A suburban woman witnesses her husbands murder...
# 2                                                   NaN
# 3                                                   NaN
# 4     A chronicle of the life of furniture salesman ...
# ...                                                 ...
# 2672  A police detective hunts down the elusive prof...
# 2673  Set against the backdrop of the Naxal movement...
# 2674                                                NaN
# 2675                                                NaN
# 2676                                                NaN
#
# [2677 rows x 7 columns]

# %%
accion.to_csv('DFFase2_accion.csv', index=False)

# %%
imdb_drama = pd.read_csv("Archivos_IMDB/drama_IMDB_clean.csv")

# %%
imdb_drama2 = imdb_drama.rename(columns={'0':'id_film','1':'Direccion','2':'Guion','3':'Puntuacion_IMDB','4':'Duracion','5':'Argumento'})

# %%
rottem_drama = pd.read_csv("Archivos_ROTTEM/rottem_drama.csv")

# %%
rottem_drama_2 = rottem_drama.rename(columns={'0':'id_film','1':'Puntuacion_Rottem'})

# %%
df_combined = pd.merge(imdb_drama2, rottem_drama_2, left_on='id_film', right_on='id_film', how='inner')

# %%
drama = df_combined[['id_film','Direccion', 'Guion','Puntuacion_IMDB','Puntuacion_Rottem','Duracion','Argumento']]

# %%
drama.to_csv('DFFase2_drama.csv', index=False)
