# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
import csv
import random
import re
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from time import sleep
import numpy as np

# %%
d_salida = {}

# %%
def llamar_api(inicio, final, genero, tipo, d_salida):

	for year in range(inicio, (final+1)):
		por_anio = {f'{year}': []}

		for page in range(1,51):
			url = "https://moviesdatabase.p.rapidapi.com/titles"

			querystring = {"genre":genero,"titleType":tipo,"year":inicio,"page":page}

			headers = {
				"X-RapidAPI-Key": "902358e2e8msh3d16b2ef47d6b52p1fc5dajsnb0a5bd959614",
				"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
			}

			response = requests.get(url, headers=headers, params=querystring)
			peliculas = response.json()
			print(f'Año: {year}. Página: {page}. Estatus: {response.status_code}')

			for pelicula in peliculas:
				por_anio[f'{year}'].append(pelicula)
	
		d_salida.update(por_anio)

# %%
llamar_api(2000, 2001, 'Drama', 'movie', d_salida)
# Out:
# Año: 2000. Página: 1. Estatus: 502
# Año: 2000. Página: 2. Estatus: 502
# Año: 2000. Página: 3. Estatus: 502
# Año: 2000. Página: 4. Estatus: 502
# Año: 2000. Página: 5. Estatus: 502
# Año: 2000. Página: 6. Estatus: 502
# Año: 2000. Página: 7. Estatus: 502
# Año: 2000. Página: 8. Estatus: 502
# Año: 2000. Página: 9. Estatus: 502
# Año: 2000. Página: 10. Estatus: 502
# Año: 2000. Página: 11. Estatus: 502
# Año: 2000. Página: 12. Estatus: 502
# Año: 2000. Página: 13. Estatus: 502
# Año: 2000. Página: 14. Estatus: 502
# Año: 2000. Página: 15. Estatus: 502
# Año: 2000. Página: 16. Estatus: 502
# Año: 2000. Página: 17. Estatus: 502
# Año: 2000. Página: 18. Estatus: 502
# Año: 2000. Página: 19. Estatus: 502
# Año: 2000. Página: 20. Estatus: 502
# Año: 2000. Página: 21. Estatus: 502
# Año: 2000. Página: 22. Estatus: 502
# Año: 2000. Página: 23. Estatus: 502
# Año: 2000. Página: 24. Estatus: 502
# Año: 2000. Página: 25. Estatus: 502
# Año: 2000. Página: 26. Estatus: 502
# Año: 2000. Página: 27. Estatus: 502
# Año: 2000. Página: 28. Estatus: 502
# Año: 2000. Página: 29. Estatus: 502
# Año: 2000. Página: 30. Estatus: 502
# Año: 2000. Página: 31. Estatus: 502
# Año: 2000. Página: 32. Estatus: 502
# Año: 2000. Página: 33. Estatus: 502
# Año: 2000. Página: 34. Estatus: 502
# Año: 2000. Página: 35. Estatus: 502
# Año: 2000. Página: 36. Estatus: 502
# Año: 2000. Página: 37. Estatus: 502
# Año: 2000. Página: 38. Estatus: 502
# Año: 2000. Página: 39. Estatus: 502
# Año: 2000. Página: 40. Estatus: 502
# Año: 2000. Página: 41. Estatus: 502
