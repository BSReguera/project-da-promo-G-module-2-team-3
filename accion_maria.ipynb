# %%
import pandas as pd
import requests
import re
import json
pd.set_option("display.max_columns",None)
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_12788\3242340523.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
diccionario_accion = {}

# %%
def extraccion_automatica(year_inicio, year_final): 

    # bucle por años (inicio, final)
    for year in range(year_inicio, (year_final + 1)):
        diccionario_por_anios = {f'{year}': []}

        # itera por páginas (1 a 50)
        for page in range(1,51):    # recordad que hay que cambiar la api KEY
            
            url = "https://moviesdatabase.p.rapidapi.com/titles"

            querystring = {"genre":"Action","year":f"{year}","page":f"{page}"}

            headers = {
                "X-RapidAPI-Key": "8e4328b22bmshd0911961ab133a2p1f61dbjsn397c1f6b789d",
                "X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
            }

            response = requests.get(url, headers=headers, params=querystring)
            print(f'Página {page}: {response.status_code}')
            peliculas = response.json()
            print('-'*10)
            
            
            for pelicula in peliculas['results']:
                diccionario_por_anios[f'{year}'].append(pelicula)

                
        # cambiar nombre aquí también
        diccionario_accion.update(diccionario_por_anios)

# %%
extraccion_automatica(2000, 2005)
# Out:
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ...

# %%
len(diccionario_accion['2005'])
# Out:
# 500

# %%
accion = {}

# %%
def criba_generos(diccionario_origen, diccionario_salida, year_primero, year_ultimo):

    for year in range(year_primero, year_ultimo):
        limpio_por_year = {f'{year}': []}

        for i in diccionario_origen[f'{year}']:
            if i['titleType']['id'] == 'movie':
                limpio_por_year[f'{year}'].append(i)
            elif i['titleType']['id'] == 'short':
                limpio_por_year[f'{year}'].append(i)
            else:
                continue
        
        diccionario_salida.update(limpio_por_year)

# %%
criba_generos(diccionario_accion, accion, 2000, 2005)

# %%
accion.keys()
# Out:
# dict_keys([])

# %%
import json
with open('accion_2023.json', 'w') as fp:
    json.dump(accion, fp)

# %%
import json
with open('accion_2023.json', 'r') as fichero:
    accion_2023 = json.load(fichero)

# %%
type(accion_2023)
# Out:
# dict

# %%
extraccion_automatica(2005, 2010)
# Out:
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ...

# %%
len(diccionario_accion['201'])
# Out:
# 500

# %%
criba_generos(diccionario_accion, accion, 2005, 2011)

# %%
accion.keys()
# Out:
# dict_keys(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010'])

# %%
import json
with open('accion_2023.json', 'w') as fp:
    json.dump(accion, fp)

# %%
import json
with open('accion_2023.json', 'r') as fichero:
    accion_2023 = json.load(fichero)

# %%
extraccion_automatica(2011, 2015)
# Out:
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ...

# %%
len(diccionario_accion['2015'])
# Out:
# 500

# %%
criba_generos(diccionario_accion, accion, 2011, 2016)

# %%
accion.keys()
# Out:
# dict_keys(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'])

# %%
import json
with open('accion_2023.json', 'w') as fp:
    json.dump(accion, fp)

# %%
import json
with open('accion_2023.json', 'r') as fichero:
    accion_2023 = json.load(fichero)

# %%
extraccion_automatica(2016, 2020)
# Out:
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ...

# %%
len(diccionario_accion['2020'])
# Out:
# 500

# %%
criba_generos(diccionario_accion, accion, 2016, 2021)

# %%
accion.keys()
# Out:
# dict_keys(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'])

# %%
import json
with open('accion_2023.json', 'w') as fp:
    json.dump(accion, fp)

# %%
import json
with open('accion_2023.json', 'r') as fichero:
    accion_2023 = json.load(fichero)

# %%
extraccion_automatica(2021, 2023)
# Out:
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ...

# %%
len(diccionario_accion['2023'])
# Out:
# 500

# %%
criba_generos(diccionario_accion, accion, 2021, 2024)

# %%
accion.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 accion.keys()
#
# NameError: name 'accion' is not defined

# %%
def lista_tuplas(origen, inicio, final):
    lista_datos = []
    for year in range(inicio, final):
        
        for i in origen[f'{year}']:
            tupla_pelicula = []
            try:
                tupla_pelicula.append(i['id'])
                tupla_pelicula.append(i["titleText"]['text'])
                tupla_pelicula.append(i['titleType']['id'])
                tupla_pelicula.append(i['releaseDate']['year'])
                tupla_pelicula.append(int(i['releaseDate']['month']))
                
            except:
                tupla_pelicula.append('X')
                
        
            lista_datos.append(tuple(tupla_pelicula))

    for i in lista_datos:
        if len(i) != 3:
            lista_datos.remove(i)
    return lista_datos

# %%
lista_tuplas(accion,2020,2023)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 lista_tuplas(accion,2020,2023)
#
# NameError: name 'accion' is not defined

# %%
import json
with open('accion_2023.json', 'w') as fp:
    json.dump(accion, fp)

# %%
import json
with open('accion_2023.json', 'r') as fichero:
    accion_2023 = json.load(fichero)

# %%
import json
with open('accion_2023.json', 'r') as fichero:
    accion_2023 = json.load(fichero)

# %%
accion_2023.keys()
# Out:
# dict_keys(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'])

# %%
accion = lista_tuplas(accion_2023,2020,2023)

# %%
import json
with open('accion.json', 'w') as fp:
    json.dump(accion, fp)
