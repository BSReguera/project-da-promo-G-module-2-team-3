# %%
import pandas as pd
import requests
import re
import json
pd.set_option("display.max_columns",None)

# %%
diccionario_drama = {}

# %%
def extraccion_automatica(year_inicio, year_final): 

    # bucle por años (inicio, final)
    for year in range(year_inicio, (year_final + 1)):
        diccionario_por_anios = {f'{year}': []}

        # itera por páginas (1 a 50)
        for page in range(1,51):    # recordad que hay que cambiar la api KEY
            
            url = "https://moviesdatabase.p.rapidapi.com/titles"

            querystring = {"genre":"Drama","year":f"{year}","page":f"{page}"}

            headers = {
                "X-RapidAPI-Key": "8e4328b22bmshd0911961ab133a2p1f61dbjsn397c1f6b789d",
                "X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
            }

            response = requests.get(url, headers=headers, params=querystring)
            print(f'Página {page}: {response.status_code}')
            peliculas = response.json()
            print('-'*10)
            
            
            for pelicula in peliculas['results']:
                diccionario_por_anios[f'{year}'].append(pelicula)

                
        # cambiar nombre aquí también
        diccionario_drama.update(diccionario_por_anios)

# %%
extraccion_automatica(2015, 2016)
# Out:
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------

# %%
len(diccionario_drama['2015'])
# Out:
# 500

# %%
drama_limpio = {}

# %%
def criba_generos(diccionario_origen, diccionario_salida, year_primero, year_ultimo):

    for year in range(year_primero, year_ultimo):
        limpio_por_year = {f'{year}': []}

        for i in diccionario_origen[f'{year}']:
            if i['titleType']['id'] == 'movie':
                limpio_por_year[f'{year}'].append(i)
            elif i['titleType']['id'] == 'short':
                limpio_por_year[f'{year}'].append(i)
            else:
                continue
        
        diccionario_salida.update(limpio_por_year)

# %%
criba_generos(diccionario_drama, drama_limpio, 2015, 2017)

# %%
drama_limpio.keys()
# Out:
# dict_keys(['2015', '2016'])

# %%
import json
with open('drama_2023.json', 'w') as fp:
    json.dump(drama_limpio, fp)

# %%
import json
with open('drama_2023.json', 'r') as fichero:
    drama_2023 = json.load(fichero)

# %%
type(drama_2023)
# Out:
# dict

# %%
drama_2023.keys()
# Out:
# dict_keys(['2015', '2016'])

# %%
extraccion_automatica(2017, 2021)
# Out:
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------

# %%
len(diccionario_drama['2021'])
# Out:
# 500

# %%
criba_generos(diccionario_drama, drama_limpio, 2017, 2022)

# %%
drama_limpio.keys()
# Out:
# dict_keys(['2015', '2016', '2017', '2018', '2019', '2020', '2021'])

# %%
drama_2023.keys()
# Out:
# dict_keys(['2015', '2016'])

# %%
import json
with open('drama_2023.json', 'w') as fp:
    json.dump(drama_limpio, fp)

# %%
import json
with open('drama_2023.json', 'r') as fichero:
    drama_2023 = json.load(fichero)

# %%
drama_2023.keys()
# Out:
# dict_keys(['2015', '2016', '2017', '2018', '2019', '2020', '2021'])

# %%
extraccion_automatica(2022, 2023)
# Out:
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------
# Página 1: 200
# ----------
# Página 2: 200
# ----------
# Página 3: 200
# ----------
# Página 4: 200
# ----------
# Página 5: 200
# ----------
# Página 6: 200
# ----------
# Página 7: 200
# ----------
# Página 8: 200
# ----------
# Página 9: 200
# ----------
# Página 10: 200
# ----------
# Página 11: 200
# ----------
# Página 12: 200
# ----------
# Página 13: 200
# ----------
# Página 14: 200
# ----------
# Página 15: 200
# ----------
# Página 16: 200
# ----------
# Página 17: 200
# ----------
# Página 18: 200
# ----------
# Página 19: 200
# ----------
# Página 20: 200
# ----------
# Página 21: 200
# ----------
# Página 22: 200
# ----------
# Página 23: 200
# ----------
# Página 24: 200
# ----------
# Página 25: 200
# ----------
# Página 26: 200
# ----------
# Página 27: 200
# ----------
# Página 28: 200
# ----------
# Página 29: 200
# ----------
# Página 30: 200
# ----------
# Página 31: 200
# ----------
# Página 32: 200
# ----------
# Página 33: 200
# ----------
# Página 34: 200
# ----------
# Página 35: 200
# ----------
# Página 36: 200
# ----------
# Página 37: 200
# ----------
# Página 38: 200
# ----------
# Página 39: 200
# ----------
# Página 40: 200
# ----------
# Página 41: 200
# ----------
# Página 42: 200
# ----------
# Página 43: 200
# ----------
# Página 44: 200
# ----------
# Página 45: 200
# ----------
# Página 46: 200
# ----------
# Página 47: 200
# ----------
# Página 48: 200
# ----------
# Página 49: 200
# ----------
# Página 50: 200
# ----------

# %%
criba_generos(diccionario_drama, drama_limpio, 2022, 2024)

# %%
import json
with open('drama_2023.json', 'w') as fp:
    json.dump(drama_limpio, fp)

# %%
import json
with open('drama_2023.json', 'r') as fichero:
    drama_2023 = json.load(fichero)

# %%
drama_2023.keys()
# Out:
# dict_keys(['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'])

# %%
def lista_tuplas(origen, inicio, final):
    lista_datos = []
    for year in range(inicio, final):
        
        for i in origen[f'{year}']:
            tupla_pelicula = []
            try:
                tupla_pelicula.append(i['id'])
                tupla_pelicula.append(i["titleText"]['text'])
                tupla_pelicula.append(i['titleType']['id'])
                tupla_pelicula.append(i['releaseDate']['year'])
                tupla_pelicula.append(i['releaseDate']['month'])
                
            except:
                tupla_pelicula.append('X')
                
        
            lista_datos.append(tuple(tupla_pelicula))

    for i in lista_datos:
        if len(i) != 3:
            lista_datos.remove(i)
    return lista_datos

# %%
lista_tuplas(drama_2023,2015,2023)
# Out:
# [('tt0297400', 'Snowblind', 'movie', 2015, None),
#  ('tt0346045', 'Transeúntes', 'movie', 2015, 4),
#  ('tt0462335', 'High-Rise', 'movie', 2016, 6),
#  ('tt0790770', 'Miles Ahead', 'movie', 2016, 4),
#  ('tt0977643', 'Chooriyan', 'movie', 2015, 6),
#  ('tt10005560', 'The Invite', 'short', 2015, 12),
#  ('tt10008620', 'Memòries', 'short', 2015, 8),
#  ('tt10022526', 'Christmas for the Rest of Us', 'short', 2015, 12),
#  ('tt0376479', 'American Pastoral', 'movie', 2016, 12),
#  ('tt0470936', 'Tak erkir, tsurt dzmer', 'movie', 2016, 5),
#  ('tt0490215', 'Silence', 'movie', 2017, 2),
#  ('tt0838194', 'Retreat!', 'movie', 2016, 8),
#  ('tt0918940', 'The Legend of Tarzan', 'movie', 2016, 7),
#  ('tt0995868', 'Pelé: Birth of a Legend', 'movie', 2016, 5),
#  ('tt10006056', 'La notte è piccola per noi', 'movie', 2019, 3),
#  ('tt10007790', 'Hum Kuchh Keh Na Sake', 'short', 2016, 4),
#  ('tt10011852', 'Saalaiyoram', 'movie', 2016, 4),
#  ('tt10023318', 'Waiting for the Boatman', 'movie', 2016, None),
#  ('tt1002563', 'The Young Messiah', 'movie', 2016, 3),
#  ('tt10029286', 'Unfriended', 'short', 2016, 4),
#  ('tt10037562', 'The 45', 'movie', 'X'),
#  ('tt10037892', 'No Phones In Class', 'short', 2016, 9),
#  ('tt10048426', 'Wistful life', 'short', 2016, 4),
#  ('tt0100275', 'La telenovela errante', 'movie', 2018, 9),
#  ('tt0269768', 'Reading Between the Lines', 'short', 2017, 10),
#  ('tt0491203', 'Tulip Fever', 'movie', 2017, 8),
#  ('tt0498381', 'Rings', 'movie', 2017, 2),
#  ('tt0835802', 'Krystal', 'movie', 2018, 4),
#  ('tt10004180', 'Ghost Walk: The Harvest Ball', 'short', 2017, 5),
#  ('tt10009896', 'The Pursuit of Love', 'short', 2017, 7),
#  ('tt10009428', 'Value', 'short', 2017, 2),
#  ('tt10016970', 'Looking Away', 'short', 2017, None),
#  ('tt10017460', 'Egise Taara Juvvalu', 'movie', 2017, 11),
#  ('tt10018590', 'Gusti', 'short', 2017, 6),
#  ('tt0192528', 'Reverse Heaven', 'movie', 2018, 11),
#  ('tt0328810', 'Aamaar Bhuvan', 'movie', 2018, 12),
#  ('tt0365545', 'Nappily Ever After', 'movie', 2018, 9),
#  ('tt0972544', 'Back Roads', 'movie', 2018, 12),
#  ('tt10004232', 'Kadogo', 'short', 2018, 10),
#  ('tt10005518', 'Brotherly Love', 'short', 2018, 12),
#  ('tt10002400', 'Form 1', 'short', 2018, 5),
#  ('tt10006220', 'Fragments', 'short', 2018, 5),
#  ('tt10010502', 'Selflove', 'short', 2018, 7),
#  ('tt10007932', 'Half the Battle', 'short', 2018, 11),
#  ('tt10010330', 'Akif', 'short', 2018, 7),
#  ('tt10010814', 'Turtle', 'movie', 2018, 7),
#  ('tt10011656', 'Flamboyante', 'short', 2018, 3),
#  ('tt10009344', 'Asphalt Saints', 'short', 2018, None),
#  ('tt10014878', 'Endgame', 'short', 2018, 11),
#  ('tt10014612', 'The Greener the Grass', 'short', 2018, None),
#  ('tt10014710', 'Honey', 'short', 2018, 3),
#  ('tt10014556', 'Turn the Switch Off', 'short', 2018, None),
#  ('tt10016858', 'Day Out', 'short', 2018, 11),
#  ('tt10021210', 'Forget Me Not', 'short', 2018, 12),
#  ('tt10021786', 'Open House', 'short', 2018, 5),
#  ('tt10026128', 'The Guide', 'short', 2018, 11),
#  ('tt10026098', 'The Other Side', 'short', 2018, 2),
#  ('tt10022338', 'I Love When You Sing to Me', 'short', 2018, 2),
#  ('tt10022852', '100 Inscritos', 'short', 2018, 7),
#  ('tt10027174', 'Saboa', 'movie', 2018, 10),
#  ('tt0083060', 'Sha Ou', 'movie', 2019, 4),
#  ('tt0339917', 'Wo men fu fu zhi jian', 'movie', 2019, 4),
#  ('tt0441881', 'Danger Close: The Battle of Long Tan', 'movie', 2019, 8),
#  ('tt0800325', 'The Dirt', 'movie', 2019, 3),
#  ('tt0858419', 'Bolden', 'movie', 2019, 5),
#  ('tt10001116', 'Mistero di un Impiegato', 'movie', 2019, 2),
#  ('tt10005030', 'Where Were You', 'short', 2019, 10),
#  ('tt10003792', 'Adalat', 'movie', 2019, 3),
#  ('tt10006156', 'Krishnam', 'movie', 2019, 3),
#  ('tt10005506', 'Witness to Murder', 'short', 2019, 3),
#  ('tt10002568', 'Voiceless', 'short', 2019, 12),
#  ('tt10003990', 'Child of Wisdom', 'movie', 2019, None),
#  ('tt10003442', 'The Coven', 'short', 2019, 4),
#  ('tt10006270', 'Jagtsæson', 'movie', 2019, 10),
#  ('tt10003828', 'Atonement', 'short', 2019, 4),
#  ('tt10003492', 'Facing Life', 'short', 2019, 3),
#  ('tt10005262', 'For Ellis', 'short', 2019, 3),
#  ('tt10004574', 'Paradise', 'movie', 2019, 4),
#  ('tt10006180', 'Destiny', 'short', 2019, 3),
#  ('tt10006764', 'Chadwick Manor', 'short', 2019, 3),
#  ('tt10005028', 'The Chair', 'short', 2019, 4),
#  ('tt10006276', "He's My Daddy Too", 'movie', 2019, 11),
#  ('tt10006238', 'Shakira', 'short', 2019, 12),
#  ('tt10005378',
#   'In Their Own Words, Billy the Kid & The Lincoln County War',
#   'movie',
#   2019,
#   12),
#  ('tt10006258', 'Motel', 'short', 2019, 6),
#  ('tt10007968', 'Partir de cero', 'short', 2019, 3),
#  ('tt10010426', "Greta's Bed & Breakfast", 'short', 'X'),
#  ('tt10010034', 'Anxiety', 'short', 2019, 1),
#  ('tt10007876', 'Memoria', 'short', 2019, 2),
#  ('tt10010626', 'Bellingham', 'short', 2019, 8),
#  ('tt10007268', 'Mesto!', 'movie', 2020, 4),
#  ('tt10010720', 'Chlorine', 'short', 2019, 6),
#  ('tt10006822', 'Winger', 'short', 2019, 5),
#  ('tt10011172', 'Andros', 'short', 'X'),
#  ('tt10009614', 'Leaves', 'short', 2019, 10),
#  ('tt10011782', "He's Mine", 'short', 2019, 6),
#  ('tt10008772', 'Something', 'short', 2019, 4),
#  ('tt10011102', 'The Sholay Girl', 'movie', 2019, 3),
#  ('tt10009434', 'Family Obligations', 'movie', 2019, 6),
#  ('tt10013050', 'Passage', 'short', 2019, 3),
#  ('tt10011986', 'Stormy', 'short', 'X'),
#  ('tt10009878', 'Encrypted: The Cyber Crime', 'movie', 2019, 5),
#  ('tt10011248', 'Lilac', 'short', 'X'),
#  ('tt10014328', 'Uncertainship', 'short', 2019, 3),
#  ('tt10014512', 'Parabola', 'short', 'X'),
#  ('tt10015768', '42', 'short', 2020, 5),
#  ('tt10014928', "It's a Small World", 'short', 2019, 5),
#  ('tt10015644', 'I Watched TV Show and Died from Blood', 'movie', 2019, 3),
#  ('tt10014298', 'Piercing Stillness', 'short', 2019, 4),
#  ('tt10014708', 'Bluefish', 'short', 2019, 1),
#  ('tt10015248', 'Kader Postasi', 'movie', 2019, 12),
#  ('tt10017074', 'Down the Barrel', 'short', 'X'),
#  ('tt10019100', 'Pick', 'short', 2019, 9),
#  ('tt10019402', 'Finals', 'movie', 2019, 9),
#  ('tt10016448', 'Fragmenter', 'short', 'X'),
#  ('tt10017060', 'Nina', 'short', 'X'),
#  ('tt10017454', 'The Purple Mist', 'movie', 2019, 2),
#  ('tt10019820', 'Saturday Grace', 'short', 2019, 8),
#  ('tt10021770', 'You Should Be on My Side', 'short', 2019, 3),
#  ('tt10022374', 'I Stem the Tide', 'short', 2019, 11),
#  ('tt10021724', 'Like Crazy', 'short', 2019, 3),
#  ('tt10021158', 'Coffee with a Madman', 'short', 2019, 2),
#  ('tt0062336', 'El Tango del Viudo y Su Espejo Deformante', 'movie', 2020, 2),
#  ('tt0446792', 'Surviving in L.A.', 'movie', 2020, 8),
#  ('tt0920462', 'Lost Girls and Love Hotels', 'movie', 2020, 9),
#  ('tt10004368', 'Jak najdalej stad', 'movie', 2021, 8),
#  ('tt10006262', 'Hear a No', 'short', 2020, 9),
#  ('tt10003008', 'The Rental', 'movie', 2020, 7),
#  ('tt10008112', 'They Never Lie', 'short', 2020, 11),
#  ('tt10010422', 'Salvage', 'short', 2020, 3),
#  ('tt10016332', 'Anxietus', 'short', 2020, 9),
#  ('tt10023074', 'Drop', 'short', 2020, 10),
#  ('tt10022726', 'Sweet Face', 'movie', 2020, 2),
#  ('tt10023024', 'Love Aaj Kal', 'movie', 2020, 5),
#  ('tt10028420', 'Nairobi', 'short', 2020, 6),
#  ('tt10032670', 'The Color of Midnight', 'short', 2020, 9),
#  ('tt10031320', 'Aur Kitna Time Lagega', 'short', 2020, 8),
#  ('tt10037824', 'Portrait', 'short', 2020, 12),
#  ('tt10039526', 'Post-You, Me', 'short', 2020, 7),
#  ('tt10038014', 'Sins Unveiled', 'short', 2020, None),
#  ('tt10042590', 'El verano que vivimos', 'movie', 2020, 12),
#  ('tt10039584', 'A Escritora', 'movie', 2020, 7),
#  ('tt10039524', 'Luxor', 'movie', 2020, 11),
#  ('tt10047998', 'The Aboves and the Belows', 'short', 2020, 12),
#  ('tt10055892', 'Youngest', 'movie', 2020, None),
#  ('tt10058872', 'Lavender', 'short', 2020, 8),
#  ('tt10061280', 'The Place of the Skull', 'short', 2020, 6),
#  ('tt10058946', 'Inner Self', 'short', 2020, 11),
#  ('tt10059822', 'La Lettre', 'short', 2020, 7),
#  ('tt10065694', 'Antebellum', 'movie', 2020, 9),
#  ('tt10066262', 'Depois de Ser Cinza', 'movie', 2020, 10),
#  ('tt10069486', 'Journey', 'short', 2020, 12),
#  ('tt10073626', 'Footsteps', 'short', 2020, None),
#  ('tt10073872', 'Días Negros', 'short', 2020, 6),
#  ('tt10074848', 'The Exchange', 'short', 2020, 2),
#  ('tt10080092', 'Wild Grass', 'movie', 2020, 8),
#  ('tt10081788', "L'oiseau de paradis", 'movie', 2020, 5),
#  ('tt10086654', 'Man of the Harvest', 'short', 2020, 11),
#  ('tt10089810', 'Boundaries', 'short', 2020, 10),
#  ('tt10092752', 'La terre et le sang', 'movie', 2020, 4),
#  ('tt10095308', 'Pink Skies Ahead', 'movie', 2020, 10),
#  ('tt10097312', 'Manchurian Tiger', 'movie', 2020, None),
#  ('tt10097484', 'Guai wu xian sheng', 'movie', 2020, 8),
#  ('tt10098068', 'Cuckoo Roller', 'short', 2020, 6),
#  ('tt10098042', 'Sunray', 'movie', 2020, 7),
#  ('tt10098776', 'Skeletons', 'short', 2020, 6),
#  ('tt10103028', 'Blindfire', 'movie', 2020, 11),
#  ('tt10102746', 'The Forgotten', 'movie', 2020, 1),
#  ('tt10110614', 'Apples', 'movie', 2022, None),
#  ('tt10106082', 'Conversaciones', 'movie', 2020, 11),
#  ('tt10107222', 'Kokon', 'movie', 2022, 7),
#  ('tt10112032', 'Askedager', 'movie', 2020, None),
#  ('tt10115320', 'Bombs Bursting in Air', 'short', 2020, None),
#  ('tt10116384', 'Toxic', 'short', 2020, 11),
#  ('tt10120260', 'Analog Rainbow', 'short', 2020, 4),
#  ('tt10123970', "Mother's Child", 'movie', 2020, 5),
#  ('tt10123128', 'Adnan', 'short', 2020, 2),
#  ('tt10123698', 'Miss', 'movie', 2021, 10),
#  ('tt10125722', 'From Gringo to Grave', 'short', 2020, 2),
#  ('tt10127684', 'Bronx', 'movie', 2020, 10),
#  ('tt10132068', 'Maryjki', 'movie', 2021, 8),
#  ('tt10132976', 'Le sel des larmes', 'movie', 2020, 7),
#  ('tt10135484', 'On the mind', 'short', 2020, 5),
#  ('tt10136434', 'Zieja', 'movie', 2020, 8),
#  ('tt10141998', 'Une journée à la mer', 'short', 2020, None),
#  ('tt10146208', 'Na ostrie', 'movie', 2020, 11),
#  ('tt10147590', 'Cerro Torre', 'movie', 2020, 5),
#  ('tt10147910', 'The Maid', 'movie', 2020, 7),
#  ('tt10150920', 'Green Summer', 'movie', 2021, 5),
#  ('tt10150238', 'The Gesture and The Word', 'short', 2020, 6),
#  ('tt10150554', 'Limited', 'short', 2020, 1),
#  ('tt10151048', 'Driftless', 'movie', 2020, 9),
#  ('tt10152582', 'Rajeeva', 'movie', 2020, 1),
#  ('tt10151656', 'The 11th Green', 'movie', 2020, 1),
#  ('tt10152722', 'Wanda, mein Wunder', 'movie', 2021, 10),
#  ('tt10156122', 'Vnutrenniy ogon', 'movie', 2020, 5),
#  ('tt10156352', 'Chen', 'short', 2020, 6),
#  ('tt10161080', 'Deep into the sea', 'short', 2020, 10),
#  ('tt10163896', 'Konglish', 'movie', 2020, 12),
#  ('tt10166648', 'Fair Haven', 'movie', 2020, 9),
#  ('tt10167422', 'Kaze no denwa', 'movie', 2020, 1),
#  ('tt10167850', 'The Heights a Perfect Reunion', 'movie', 2020, 2),
#  ('tt10174310', 'Pink Pool', 'short', 2020, 1),
#  ('tt10171548', 'Yarne', 'short', 2020, 11),
#  ('tt10182142', 'Anchor', 'short', 2020, 11),
#  ('tt10175932', 'King Daniel', 'short', 2020, 8),
#  ('tt10181344', 'Ayaan', 'short', 2020, None),
#  ('tt10182416', 'The Love Prank', 'short', 2020, None),
#  ('tt10183816', 'Dangerous Lies', 'movie', 2020, 4),
#  ('tt10187378', 'Cordero de Dios', 'movie', 2020, 1),
#  ('tt10188656', 'Clarity', 'short', 2020, 2),
#  ('tt10189514', 'Soorarai Pottru', 'movie', 2020, 11),
#  ('tt10194706', 'In My Eyes', 'short', 2020, 10),
#  ('tt10196304', 'Dad Was', 'short', 2020, 11),
#  ('tt10197570', 'The Tree Movie', 'movie', 2020, 4),
#  ('tt10198274', "Mia's M.I.A", 'movie', 2020, None),
#  ('tt10199238', '#shootme', 'short', 2020, 7),
#  ('tt10199914', 'The Boys in the Band', 'movie', 2020, 9),
#  ('tt10203126', 'Happy Birthday, My Love', 'short', 2020, 12),
#  ('tt10203432', 'Fleeting', 'short', 2020, 11),
#  ('tt0228802', 'Mugen ryûkyû tsuru Henrî', 'movie', 2021, 5),
#  ('tt0346172', 'Zamaanat: And Justice for All', 'movie', 2021, None),
#  ('tt0840306', 'Cosmic Radio', 'movie', 2021, 2),
#  ('tt10003618', 'Kelti', 'movie', 2021, 12),
#  ('tt10011052', 'Milkshake', 'short', 2021, 12),
#  ('tt10023286', 'The Humans', 'movie', 2021, 11),
#  ('tt10032574', 'Pure White', 'movie', 2021, 6),
#  ('tt10033714', 'Garden of Paradise', 'short', 2021, 12),
#  ('tt10042788', 'Promises', 'movie', 2021, 11),
#  ('tt10040326', 'Welcome to Mumbai', 'short', 2021, 3),
#  ('tt10051000', 'Sans soleil', 'movie', 2021, 10),
#  ('tt10049710', 'The Long Halloween', 'short', 2021, 10),
#  ('tt10062628', 'Sombra', 'movie', 2021, 10),
#  ('tt10062556', 'Bhuj: The Pride of India', 'movie', 2021, 8),
#  ('tt10072662', 'Il materiale emotivo', 'movie', 2021, 10),
#  ('tt10077034', 'Twist', 'movie', 2021, 6),
#  ('tt10079796', 'The Wasteland of Education', 'movie', 2021, 10),
#  ('tt10084832', 'Nomad', 'movie', 2021, None),
#  ('tt10095582', 'The Tragedy of Macbeth', 'movie', 2021, 12),
#  ('tt10098452', 'Animals', 'movie', 2021, 10),
#  ('tt10108062', 'Lavinya', 'movie', 2021, None),
#  ('tt10115874', 'The Diary: An Untold Story', 'movie', 2021, None),
#  ('tt10121222', 'Paul Keller - Stille im Schrei', 'movie', 2021, 9),
#  ('tt10121942', 'Inside the Notebook', 'short', 2021, 1),
#  ('tt10126040', 'The Exchange', 'movie', 2021, 7),
#  ('tt10130050', 'Girls Are Strong Here', 'short', 2021, 2),
#  ('tt10137298', 'God in the Sky', 'short', 2021, 11),
#  ('tt10152736', 'Thalaivi', 'movie', 2021, 9),
#  ('tt10160440', 'R[evol]ution of Love', 'short', 2021, 1),
#  ('tt10160948', 'A Living Sculpture', 'short', 2021, 1),
#  ('tt10162788', 'Peninsula', 'short', 2021, 6),
#  ('tt10165720', 'The Road Kid', 'short', 2021, None),
#  ('tt10173624', "Don't kill my dreams", 'short', 2021, None),
#  ('tt10187208', 'A Boy Called Christmas', 'movie', 2021, 11),
#  ('tt10196108', 'Eugénie Grandet', 'movie', 2021, 9),
#  ('tt10197632', 'Woman in Car', 'movie', 2021, 3),
#  ('tt10202368', 'Growing Season', 'short', 2021, None),
#  ('tt10211236', 'Nada de Bom acontece depois dos 30', 'short', 2021, 7),
#  ('tt10217312', 'The Exit Interview', 'short', 2021, None),
#  ('tt10221732', 'Madison Baker Was Here', 'movie', 2021, 11),
#  ('tt10223204', 'Playboy Eddy', 'short', 2021, 2),
#  ('tt10229068', 'Birdie', 'movie', 2021, 4),
#  ('tt10230994', 'Beckett', 'movie', 2021, 8),
#  ('tt10232096', 'Buran', 'movie', 2021, 12),
#  ('tt10241130', 'Three Legged Horse', 'movie', 2021, None),
#  ('tt10255620', 'Cookie', 'short', 2021, 2),
#  ('tt10265126', 'Four Strokes', 'short', 2021, 2),
#  ('tt10263160', 'Bedtime story for ghosts', 'short', 2021, 8),
#  ('tt10265034', 'Land', 'movie', 2021, 6),
#  ('tt10265764', 'Lucia, Lucia', 'movie', 2021, 5),
#  ('tt10268316', 'Not a Slave', 'movie', 2021, 3),
#  ('tt10270250', 'Dusty to Meet Rusty', 'movie', 2021, 12),
#  ('tt10280296', 'Sardar Udham', 'movie', 2021, 10),
#  ('tt10288032', 'Proof of God', 'short', 2021, 6),
#  ('tt10290352', 'Il cattivo poeta', 'movie', 2021, 5),
#  ('tt10293032', 'Graduation Afternoon', 'short', 2021, 1),
#  ('tt10298870', 'La Flamme Rouge', 'movie', 2021, 11),
#  ('tt10300570', 'Kadaisi Vivasayi', 'movie', 2021, 2),
#  ('tt10308068', 'Aimbot', 'short', 2021, None),
#  ('tt10308502', 'An Intrusion', 'movie', 2021, 9),
#  ('tt10311018', 'Okul Tirasi', 'movie', 2021, 10),
#  ('tt10313738', 'Esther & Maude', 'movie', 2021, 10),
#  ('tt10318096', 'Reunion of Champions', 'movie', 2021, 6),
#  ('tt10324186', 'Le Sablier', 'short', 2021, 9),
#  ('tt10332270', 'Years', 'short', 2021, 9),
#  ('tt10333426', 'Bliss', 'movie', 2021, 2),
#  ('tt10337974', 'Dougley', 'movie', 2021, None),
#  ('tt10339052', 'Best Sellers', 'movie', 2021, 10),
#  ('tt10342730', 'Spiral: From the Book of Saw', 'movie', 2021, 6),
#  ('tt10345782', 'La scuola cattolica', 'movie', 2021, 10),
#  ('tt10348936', 'The Girl Sitting Here', 'short', 2021, 6),
#  ('tt10350572', 'The Good Balloon', 'short', 2021, 2),
#  ('tt10353864', "Ts'ekoo Cha Ke: The Girl with Big Feet", 'short', 2021, None),
#  ('tt10360860', 'Things Worth Weeping For', 'movie', 2021, 9),
#  ('tt10365704', 'Gris', 'short', 2021, None),
#  ('tt10367074', 'Red Sandra', 'movie', 2021, 9),
#  ('tt10366574', 'Noche de fuego', 'movie', 2021, 9),
#  ('tt10363182', 'Tab', 'short', 2021, 2),
#  ('tt10368680', 'Below the Fold', 'movie', 2021, 11),
#  ('tt10370710', 'The Worst Person in the World', 'movie', 2022, 2),
#  ('tt10375916', 'Blindsided', 'movie', 2021, 4),
#  ('tt10376078', 'Inni ludzie', 'movie', 2022, 3),
#  ('tt10376530', 'Dogs', 'short', 2021, 3),
#  ('tt10376800', 'Petite Solange', 'movie', 2022, 2),
#  ('tt10378806', 'Suspended', 'short', 2021, 9),
#  ('tt10384534', 'Silent River', 'movie', 2021, 9),
#  ('tt10383780', 'Marco & Polo Go Round', 'short', 2021, 6),
#  ('tt10388514', 'Slot', 'short', 2021, 8),
#  ('tt10396450', 'Karmalink', 'movie', 2021, 9),
#  ('tt10400028', 'I Am Zlatan', 'movie', 2022, 1),
#  ('tt10402840', 'The Truth Has Changed', 'movie', 2021, 3),
#  ('tt10406596', 'You Are Not My Mother', 'movie', 2022, 3),
#  ('tt10413092', "Hope's Legacy", 'movie', 2021, 1),
#  ('tt10415684', 'Hasadék', 'movie', 2021, 9),
#  ('tt10426186', 'Seelenschatten', 'short', 2021, 1),
#  ('tt10431556', 'Untitled Walking Distance Horror Project', 'movie', 'X'),
#  ('tt10426580', 'We Burn Like This', 'movie', 2021, 4),
#  ('tt10431414', "The Bertelli's", 'movie', 2021, 9),
#  ('tt10433734', 'Tinerete, dulce batranete...', 'short', 2021, None),
#  ('tt10441878', 'A Mesma Parte de Um Homem', 'movie', 2021, 1),
#  ('tt10448124', 'West Michigan', 'movie', 2021, 4),
#  ('tt10449406', 'Petra', 'short', 2021, None),
#  ('tt10457168', 'My Fiona', 'movie', 2021, 11),
#  ('tt10463270', 'Shouting Silence', 'movie', 2021, 9),
#  ('tt10473008', 'The Coffin Bound Kings', 'movie', 2021, 3),
#  ('tt10479784', 'Riding Liberty', 'short', 2021, 10),
#  ('tt10482866', 'Captive', 'short', 2021, 3),
#  ('tt10482032', 'Implosion', 'movie', 2021, 3),
#  ('tt10482844', 'Time Now', 'movie', 2021, 10),
#  ('tt10487984', 'A Mutual Understanding', 'short', 2021, 9),
#  ('tt10504992', 'Basenji', 'movie', 2021, None),
#  ('tt10503736', 'The Ghosts of Borley Rectory', 'movie', 2021, 10),
#  ('tt10514056', 'Unsilenced', 'movie', 2022, 1),
#  ('tt10510280', "School's Out Forever", 'movie', 2021, 2),
#  ('tt10517736', 'Silver Flask', 'short', 2021, 4),
#  ('tt10518812', 'Radley', 'short', 2021, None),
#  ('tt10522608', 'The Award Ceremony', 'short', 2021, 4),
#  ('tt10526266', 'Räuberhände', 'movie', 2021, 9),
#  ('tt10533540', 'Rachel in the Dark Room', 'short', 2021, 11),
#  ('tt10544106', 'The Hole', 'short', 2021, 5),
#  ('tt10544328', 'El camino de Sol', 'movie', 2021, 11),
#  ('tt10545658', 'Okiagari', 'short', 2021, 1),
#  ('tt10546172', 'Boshack', 'short', 2021, 10),
#  ('tt10551584', 'Being Brave', 'short', 2021, 1),
#  ('tt10553930', 'The Truth About Dreaming', 'short', 2021, None),
#  ('tt10556756', 'Who is Sleeping in Silver Grey', 'movie', 2021, 11),
#  ('tt10560282', 'Eingehüllt', 'short', 2021, 10),
#  ('tt10573984', 'Koko', 'movie', 2021, 2),
#  ('tt10572658', 'Collection', 'movie', 2021, 9),
#  ('tt10589738', 'Libertad', 'movie', 2021, 11),
#  ('tt10592782', 'Othaniel', 'short', 2021, None),
#  ('tt10603372', 'Le Prince', 'movie', 2021, 9),
#  ('tt10607372', 'The Horrible Hunters', 'movie', 2021, 12),
#  ('tt10608854', 'Maskhara', 'movie', 2021, 12),
#  ('tt10616984', "It's What's On the Inside", 'movie', 2021, 4),
#  ('tt10622284', 'A Chant', 'short', 2021, 2),
#  ('tt10618682', 'Addict Named Hal', 'movie', 2021, 4),
#  ('tt10627274', 'El Blanco', 'movie', 2021, 10),
#  ('tt10634918', 'Port Tesaturi', 'short', 2021, None),
#  ('tt10636130', 'Making Sense', 'movie', 2021, 4),
#  ('tt10644372', 'Lone Wolf', 'movie', 2021, 9),
#  ('tt10648352', 'Awaken', 'short', 2021, 5),
#  ('tt10652948', 'Undertaker', 'movie', 2021, 7),
#  ('tt10656034', 'Moras biti ziv da bi umro', 'movie', 2021, 1),
#  ('tt10661100', 'The Last Darling Bulgaria', 'movie', 2021, 5),
#  ('tt10661710', 'Born a Champion', 'movie', 2021, 1),
#  ('tt10671328', 'Angrej Putt', 'movie', 2021, 4),
#  ('tt10670754', 'Paranormal Investigators', 'movie', 2021, None),
#  ('tt10674614', 'Ashley Jones Is Perfectly Normal', 'movie', 2021, 11),
#  ('tt10681682', 'Sorry for Your Loss', 'short', 2021, 10),
#  ('tt10685024', '1969', 'short', 2021, 2),
#  ('tt10687016', 'Asbury Park', 'movie', 2021, 11),
#  ('tt10687506', 'The Electrical Life of Louis Wain', 'movie', 2021, 12),
#  ('tt0965381', 'Milli Vanilli', 'movie', 2022, None),
#  ('tt10003926', 'Siempre Yo', 'short', 2022, 3),
#  ('tt10047904', 'Darkling', 'movie', 2022, 4),
#  ('tt10064134', 'The Reunion', 'movie', 2022, 1),
#  ('tt10092362', "Pastor's Wife", 'movie', 2022, None),
#  ('tt3704428', 'Elvis', 'movie', 2022, 6),
#  ('tt10141678', 'Fate of the Night', 'movie', 2022, 7),
#  ('tt10150354', 'The Four Fathers', 'movie', 2022, None),
#  ('tt1016150', 'Im Westen nichts Neues', 'movie', 2022, 10),
#  ('tt10192406', 'Causeway', 'movie', 2022, 11),
#  ('tt10250868', 'Immenhof - La grande promessa', 'movie', 2022, 5),
#  ('tt10270204', 'La voluntaria', 'movie', 2022, 6),
#  ('tt10298810', 'Lightyear', 'movie', 2022, 6),
#  ('tt10303920', 'Toxicos', 'short', 2022, 11),
#  ('tt10321490', 'Levi Roots', 'movie', None, None),
#  ('tt10332372', 'Paki', 'movie', 2022, None),
#  ('tt10343626', 'Price', 'short', 2022, 10),
#  ('tt10354106', 'Stars at Noon', 'movie', 2022, 10),
#  ('tt10360808',
#   'La vaca que cantó una canción hacia el futuro',
#   'movie',
#   2022,
#   1),
#  ('tt10373344', "Fisherman's Friends: One and All", 'movie', 2022, 11),
#  ('tt10379142', 'Hallowtide', 'movie', 2022, 4),
#  ('tt10387560', 'La piel ajena', 'movie', 2022, None),
#  ('tt10399628', 'A life like any other', 'movie', 2022, 10),
#  ('tt10422498', 'Cousins', 'short', 2022, None),
#  ('tt10449310', 'Aylan Baby', 'movie', 2022, 3),
#  ('tt10478422', 'The Year of the Soul', 'movie', 2022, 9),
#  ('tt10512248', 'North Central', 'movie', 2022, 12),
#  ('tt10518176', 'Padavettu', 'movie', 2022, 11),
#  ('tt10545696', 'Maigret', 'movie', 2022, 2),
#  ('tt10597604', 'Scarecrow', 'short', 2022, 12),
#  ('tt10608624', 'Veyil', 'movie', 2022, 2),
#  ('tt10628016', 'Inside', 'short', 2022, 1),
#  ('tt10648938', 'Side Effects', 'movie', 2022, None),
#  ('tt10653054', 'I Love You, Guys', 'short', 2022, 5),
#  ('tt10674504', 'Campo de Sangue', 'movie', 2022, 6),
#  ('tt10687220', 'Nikamma', 'movie', 2022, 6),
#  ('tt10696052', 'The Deal', 'short', 2022, 6),
#  ('tt10701764', 'True to Life', 'short', 2022, 11),
#  ('tt10698680', 'K.G.F: Chapter 2', 'movie', 2022, 4),
#  ('tt10710018', 'Sexagenarian', 'movie', 'X'),
#  ('tt10731256', 'Nie martw się, kochanie', 'movie', 2022, 9),
#  ('tt10737918', 'Shin Ultraman', 'movie', 2022, 5),
#  ('tt10743778', 'Abiding', 'movie', 2022, 8),
#  ('tt10749948', 'Serdtse parmy', 'movie', 2022, 10),
#  ('tt10767774', 'Making Friends as the World Ends', 'movie', 2022, 6),
#  ('tt10771320', 'Avalon Drive', 'short', 2022, None),
#  ('tt10788058', 'Come Out Fighting', 'movie', 2022, 11),
#  ('tt10789216', 'Diary of a Spy', 'movie', 2022, 7),
#  ('tt10821268', 'Astroman', 'short', 2022, 2),
#  ('tt10832880', 'A Strippers Prayer', 'movie', 2022, 1),
#  ('tt10865174', 'EAMI', 'movie', 2022, 9),
#  ('tt10881156', 'Stay with Me', 'movie', 2022, None),
#  ('tt10904808', 'Krime Story', 'movie', 2022, 2),
#  ('tt10923334', 'Herseye Ragmen', 'movie', 2023, 2),
#  ('tt10934192', 'The Resonance Principle', 'short', 2022, 4),
#  ('tt10931784', 'Nanny', 'movie', 2022, 12),
#  ('tt10937932', 'Back to Billy', 'movie', 2022, 12),
#  ('tt10953232', 'Bristol Fashion', 'movie', 2022, 6),
#  ('tt10956432', 'The Journey of Gabe', 'movie', None, None),
#  ('tt10984980', 'La Vida en el Silencio', 'movie', 2022, None),
#  ('tt10999998', 'Main Hoon Auto Wala', 'movie', 2022, 11),
#  ('tt11013696', 'The Land of Dreams', 'movie', 2022, 11),
#  ('tt11023732', 'Virata Parvam', 'movie', 2022, 6),
#  ('tt11044144', 'Eagle Rock', 'movie', 2022, None),
#  ('tt11063938', 'Essence of Love', 'short', 2022, 1),
#  ('tt11073838', 'Enough', 'short', 2022, None),
#  ('tt11096882', 'Of the Son', 'movie', 2022, None),
#  ('tt11112784', 'Perfect Strangers', 'movie', 2022, 1),
#  ('tt11116912', 'Troll', 'movie', 2022, 12),
#  ('tt11137920', 'Garuda', 'movie', 2022, 5),
#  ('tt11167918', 'Chroma', 'movie', 2022, 7),
#  ('tt11177996', 'Hawayein', 'movie', 2022, 6),
#  ('tt11182810', 'AI Love You', 'movie', 2022, 2),
#  ('tt11203022', 'Sex Appeal', 'movie', 2022, 4),
#  ('tt11202078', 'Transgressing', 'short', 2022, None),
#  ('tt11237650', 'Wisdom for Heroes', 'movie', 2022, None),
#  ('tt11247732', 'Diné', 'short', 2022, 11),
#  ('tt11257188', 'The Fever', 'movie', 2022, 9),
#  ('tt11278476', 'Rescued by Ruby', 'movie', 2022, 3),
#  ('tt11279006', 'The German King', 'movie', None, None),
#  ('tt11286592', 'Vermelho Monet', 'movie', 2022, 12),
#  ('tt11295246', 'Good Luck Sakhi', 'movie', 2022, 1),
#  ('tt11327288', 'US vs. THEM', 'movie', None, None),
#  ('tt11348008', 'Life After You', 'short', None, None),
#  ('tt11365186', 'Redeeming Love', 'movie', 2022, 1),
#  ('tt11375428', 'Hridayam', 'movie', 2022, 1),
#  ('tt11379988', 'James', 'movie', 2022, 3),
#  ('tt11397180', 'Kendi Yolumda', 'movie', 2022, 11),
#  ('tt11406104', 'Dä Wätterschmöcker', 'movie', None, None),
#  ('tt11423420', 'Please Baby Please', 'movie', 2022, 11),
#  ('tt11436640', 'Oskars Kleid', 'movie', 2022, 12),
#  ('tt11448016', 'Midland Club', 'movie', 2022, None),
#  ('tt11460992', 'Runway 34', 'movie', 2022, 4),
#  ('tt11468144', 'Filthy Animals', 'movie', 2022, 11),
#  ('tt11497848', 'Meridiane Story', 'movie', 2022, 11),
#  ('tt11513472', 'Family Portrait', 'short', 2022, 9),
#  ('tt11524502', 'Say Goodbye', 'movie', 2022, 3),
#  ('tt11530796', 'Los Patines', 'short', 2022, 6),
#  ('tt11531182', 'Ajayante Randam Moshanam', 'movie', 2022, None),
#  ('tt11540726', 'Resurrection', 'movie', 2022, 8),
#  ('tt11563070', 'Acharya', 'movie', 2022, 4),
#  ('tt11579056', 'The Lego Batman and Spider-Man Movie', 'short', 2022, 1),
#  ('tt1161401', 'The American Can', 'movie', 2022, None),
#  ('tt11628208', 'North of Normal', 'movie', 2022, 9),
#  ('tt11646442', 'Tootu Madike', 'movie', 2022, 7),
#  ('tt11650840', 'Taxi Driver Uncut', 'short', 2022, 8),
#  ('tt11663184', 'Chowki', 'movie', 2022, None),
#  ('tt11671404', 'Vadio', 'movie', 2022, 11),
#  ('tt11684438',
#   "Nobody Loves You and You Don't Deserve to Exist",
#   'movie',
#   2022,
#   None),
#  ('tt11701940', 'Abandoned', 'short', 2022, None),
#  ('tt11703050', 'The House', 'movie', 2022, 1),
#  ('tt11706558', 'Fang', 'movie', 2022, 11),
#  ('tt11729844', 'Vlihi', 'short', 2022, 5),
#  ('tt11733110', 'Rebound', 'short', 2022, None),
#  ('tt11775244', 'Omnibus 9', 'movie', 2022, None),
#  ('tt11790062', 'Encounter', 'short', 2022, None),
#  ('tt11799764', 'Merindu Cahaya de Amstel', 'movie', 2022, 1),
#  ('tt11804356', 'Tsunami', 'movie', 2022, 12),
#  ('tt11827166', 'Aurora', 'movie', 2022, None),
#  ('tt11854326', 'Ero in guerra ma non lo sapevo', 'movie', 2022, 1),
#  ('tt11867432', 'Encontro', 'movie', 2022, 9),
#  ('tt11885520', 'Ghost of the Lake', 'short', 2022, None),
#  ('tt11897978', 'Punch!', 'movie', None, None),
#  ('tt11898996', 'Odwrócona wieża', 'movie', 2022, 9),
#  ('tt11930126', 'Alcarrás', 'movie', 2022, 4),
#  ('tt11934038', 'El fred que crema', 'movie', 2023, 1),
#  ('tt11939970', 'Entropy', 'movie', 2022, 1),
#  ('tt11953194', 'Hey Sinamika', 'movie', 2022, 4),
#  ('tt11953120', 'Paragate', 'movie', None, None),
#  ('tt11963006', 'Relative', 'movie', 2022, 3),
#  ('tt11987258', 'Neon Spring', 'movie', 2022, None),
#  ('tt11995882', 'ShadowMarsh', 'movie', 2022, 2),
#  ('tt12015102', 'Vikrant Rona', 'movie', 2022, 7)]

# %%
drama = lista_tuplas(drama_2023,2015,2023)

# %%
df_drama = pd.DataFrame(drama)

# %%
df_drama
# Out:
#               0             1      2     3    4
# 0     tt0297400     Snowblind  movie  2015  NaN
# 1     tt0346045   Transeúntes  movie  2015  4.0
# 2     tt0462335     High-Rise  movie  2016  6.0
# 3     tt0790770   Miles Ahead  movie  2016  4.0
# 4     tt0977643     Chooriyan  movie  2015  6.0
# ..          ...           ...    ...   ...  ...
# 501  tt11953120      Paragate  movie  None  NaN
# 502  tt11963006      Relative  movie  2022  3.0
# 503  tt11987258   Neon Spring  movie  2022  NaN
# 504  tt11995882   ShadowMarsh  movie  2022  2.0
# 505  tt12015102  Vikrant Rona  movie  2022  7.0
#
# [506 rows x 5 columns]
