# %%
pip install pandas sqlalchemy
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 653.6 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.3/2.1 MB 2.8 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.1 MB 4.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.1 MB 5.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.1 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/293.6 kB ? eta -:--:--
#    --------------------------------------- 293.6/293.6 kB 17.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

from sqlalchemy import create_engine

import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
# Out:
# C:\Users\bsanc\AppData\Local\Temp\ipykernel_6288\993339502.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
peliculas_df = pd.read_csv('Fase1_datos/Archivos_definitivos/fase1_total_completo.csv')

# %%
det_peliculas_df = pd.read_csv('Fase2_datos/DF_definitivos/df_detalles_peliculas.csv')

# %%
peliculas_df
# Out:
#       id_pelicula  Genero                  Titulo   Tipo Año_estreno  \
# 0       tt0113092  accion           For the Cause  movie        2002
# 1       tt0116391  accion                    Gang  movie        2000
# 2       tt0116628  accion        The Incorporated  movie        2000
# 3       tt0119273  accion        Heavy Metal 2000  movie        2000
# 4       tt0120755  accion  Mission: Impossible II  movie        2000
# ...           ...     ...                     ...    ...         ...
# 13472  tt16437278   drama              The Strays  movie        2023
# 13473   tt7984562   drama                 Statica  movie        2023
# 13474  tt16431882   drama             Brooklyn 45  movie        2023
# 13475  tt16369708   drama         Yaneura no Raja  movie        2023
# 13476   tt8593824   drama             The Old Way  movie        2023
#
#       Mes_estreno
# 0               5
# 1               4
# 2             NaN
# 3               5
# 4               7
# ...           ...
# ...

# %%
def quitar_espacios_en_blanco(fila):
    return fila.strip() if isinstance(fila, str) else fila

# %%
peliculas_df['Año_estreno'] = peliculas_df['Año_estreno'].apply(lambda x: quitar_espacios_en_blanco(x))

# %%
print(peliculas_df['Año_estreno'].str.len().max())
# Out:
# 11.0

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='proyecto_pelis')

print(cnx)
cnx.close()


engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@localhost/proyecto_pelis')


peliculas_df.to_sql('peliculas', con=engine, if_exists='append', index=False)
# Out:
# ...
# -1

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='proyecto_pelis')

print(cnx)
cnx.close()


engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@localhost/proyecto_pelis')


det_peliculas_df.to_sql('Detalles_Peliculas', con=engine, if_exists='append', index=False)
# Out:
# ...
# C:\Users\maria\AppData\Local\Temp\ipykernel_10924\1771935125.py:12: UserWarning: The provided table name 'Detalles_Peliculas' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   det_peliculas_df.to_sql('Detalles_Peliculas', con=engine, if_exists='append', index=False)
# -1

# %%
detalle_actores_df = pd.read_csv('Fase3_datos/Archivos_definitivos/detalle_actores_2.csv')

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='proyecto_pelis')

print(cnx)
cnx.close()


engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@localhost/proyecto_pelis')


detalle_actores_df.to_sql('Actores', con=engine, if_exists='append', index=False)
# Out:
# ...
# C:\Users\maria\AppData\Local\Temp\ipykernel_10924\1223911296.py:12: UserWarning: The provided table name 'Actores' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   detalle_actores_df.to_sql('Actores', con=engine, if_exists='append', index=False)
# -1

# %%
Actores_df = pd.read_csv('Fase3_datos/Archivos_definitivos/Actores.csv')

# %%
Actores_df
# Out:
#           id_film    id_actor
# 0       tt0113092   nm0001002
# 1       tt0113092   nm0001299
# 2       tt0113092   nm0923529
# 3       tt0113092   nm0936365
# 4       tt0113086   nm0868692
# ...           ...         ...
# 51301  tt18690646   nm2718952
# 51302  tt18748860   nm7044283
# 51303  tt18748860  nm13494449
# 51304  tt18748860   nm3428007
# 51305  tt18748860   nm2146289
#
# [51306 rows x 2 columns]

# %%
columnas = {'id_film':'id_pelicula'}

# %%
Actores_df = Actores_df.rename(columns={'id_film':'id_pelicula'})

# %%
Actores_df
# Out:
#       id_pelicula    id_actor
# 0       tt0113092   nm0001002
# 1       tt0113092   nm0001299
# 2       tt0113092   nm0923529
# 3       tt0113092   nm0936365
# 4       tt0113086   nm0868692
# ...           ...         ...
# 51301  tt18690646   nm2718952
# 51302  tt18748860   nm7044283
# 51303  tt18748860  nm13494449
# 51304  tt18748860   nm3428007
# 51305  tt18748860   nm2146289
#
# [51306 rows x 2 columns]

# %%
Actores_df.to_csv('Fase3_datos/Archivos_definitivos/Actores_df.csv', index=False)

# %%
Actores_df = pd.read_csv('Fase3_datos/Archivos_definitivos/Actores_df.csv')

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='proyecto_pelis')

print(cnx)
cnx.close()


engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@localhost/proyecto_pelis')


Actores_df.to_sql('Peli_actor', con=engine, if_exists='append', index=False)
# Out:
# ...
# C:\Users\maria\AppData\Local\Temp\ipykernel_15560\1504800688.py:12: UserWarning: The provided table name 'Peli_actor' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Actores_df.to_sql('Peli_actor', con=engine, if_exists='append', index=False)
# -1

# %%
tabla_oscar = pd.read_csv('Fase4_datos/tabla_oscar.csv')

# %%
tabla_oscar
# Out:
#                Ceremonia id_pelicula  \
# 0        26 de marzo2000   tt0169547
# 1        25 de marzo2001   tt0172495
# 2     24 de marzode 2002   tt0268978
# 3     23 de marzode 2003   tt0299658
# 4   29 de febrerode 2004   tt0167260
# 5   27 de febrerode 2005   tt0405159
# 6      5 de marzode 2006   tt0375679
# 7   25 de febrerode 2007   tt0407887
# 8   24 de febrerode 2008   tt0477348
# 9   22 de febrerode 2009   tt1010048
# 10     7 de marzode 2010   tt0887912
# 11  27 de febrerode 2011   tt1504320
# 12  26 de febrerode 2012   tt1655442
# 13  24 de febrerode 2013   tt1024648
# 14     2 de marzode 2014   tt2024544
# 15  22 de febrerode 2015   tt2562232
# 16  28 de febrerode 2016   tt1895587
# 17  26 de febrerode 2017   tt4975722
# 18     4 de marzode 2018   tt5580390
# 19  24 de febrerode 2019   tt6966692
# 20   9 de febrerode 2020   tt6751668
# 21    25 de abrilde 2021   tt9770150
# 22    27 de marzode 2022  tt10366460
# 23    12 de marzode 2023   tt6710474
#
# ...

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='proyecto_pelis')

print(cnx)
cnx.close()


engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@localhost/proyecto_pelis')


tabla_oscar.to_sql('Premios', con=engine, if_exists='append', index=False)
# Out:
# ...
# C:\Users\maria\AppData\Local\Temp\ipykernel_15560\3275529325.py:12: UserWarning: The provided table name 'Premios' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   tabla_oscar.to_sql('Premios', con=engine, if_exists='append', index=False)
# -1

# %%
Tabla_premios = pd.read_csv('actores_awards_definitiva.csv')

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='proyecto_pelis')

print(cnx)
cnx.close()


engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@localhost/proyecto_pelis')


Tabla_premios.to_sql('actor_premio', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
#       2                               host='127.0.0.1',
#       3                               database='proyecto_pelis')
#       5 print(cnx)
#       6 cnx.close()
#
# File c:\Users\bsanc\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File c:\Users\bsanc\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# ...
