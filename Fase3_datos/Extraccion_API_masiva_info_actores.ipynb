# %%
import pandas as pd

# Especifica la ruta de tu archivo TSV
ruta_archivo_tsv = 'C:\\Users\\maria\\Downloads\\name.basics.tsv.gz'

# Utiliza read_csv con el delimitador '\t' para archivos TSV
data = pd.read_csv(ruta_archivo_tsv, delimiter='\t')

# Ahora 'data' es un DataFrame de Pandas que contiene tus datos
# Puedes realizar operaciones y análisis de datos utilizando Pandas
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_12748\4289744621.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import numpy as np
import json
import pandas as pd

# %%
data.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0027125,tt0072308,tt0053137
# 1  tt0117057,tt0075213,tt0038355,tt0037382
# 2  tt0057345,tt0056404,tt0049189,tt0054452
# 3  tt0080455,tt0078723,tt0072562,tt0077975
# 4  tt0050986,tt0050976,tt0083922,tt0069467

# %%
df_accion = pd.read_csv('actores_accion.csv')

# %%
df_accion.head()
# Out:
#       tconst  ordering     nconst category job       characters
# 0  tt0113092         1  nm0001002    actor  \N  ["Gen. Murran"]
# 1  tt0113092         2  nm0001299    actor  \N        ["Evans"]
# 2  tt0113092         3  nm0923529    actor  \N   ["Sutherland"]
# 3  tt0113092         4  nm0936365  actress  \N         ["Abel"]
# 4  tt0116391         1  nm0006763    actor  \N        ["Gangu"]

# %%
df_combined = pd.merge(df_accion, data, left_on='nconst', right_on='nconst', how='inner')

# %%
df_combined
# Out:
#            tconst  ordering      nconst category job             characters  \
# 0       tt0113092         1   nm0001002    actor  \N        ["Gen. Murran"]
# 1       tt0113092         2   nm0001299    actor  \N              ["Evans"]
# 2       tt0113092         3   nm0923529    actor  \N         ["Sutherland"]
# 3       tt0113092         4   nm0936365  actress  \N               ["Abel"]
# 4       tt0116391         1   nm0006763    actor  \N              ["Gangu"]
# ...           ...       ...         ...      ...  ..                    ...
# 13729  tt21294600         1  nm13745033    actor  \N              ["Morto"]
# 13730  tt21435580         1   nm3435639  actress  \N      ["Natalia Pérez"]
# 13731  tt21435580         2   nm4749252  actress  \N    ["Vanessa Fonseca"]
# 13732  tt21435580         3   nm3726552    actor  \N  ["Dr. Olman de la O"]
# 13733  tt21435580         4   nm6898648  actress  \N               ["Sara"]
#
#                       primaryName birthYear deathYear  \
# ...

# %%
actores_accion_detalles = df_combined[['primaryName', 'birthYear', 'deathYear', 'primaryProfession','knownForTitles']]

# %%
actores_accion_detalles
# Out:
#                       primaryName birthYear deathYear  \
# 0                       Dean Cain      1966        \N
# 1             Thomas Ian Griffith      1962        \N
# 2                   Justin Whalin      1974        \N
# 3                Jodi Bianca Wise      1971        \N
# 4                   Jackie Shroff      1957        \N
# ...                           ...       ...       ...
# 13729                 Nick Miller        \N        \N
# 13730            Viviana Calderón        \N        \N
# 13731              Johanna Solano        \N        \N
# 13732                Jaime Castro        \N        \N
# 13733  Maria Jose Pereira Herrera        \N        \N
#
#                primaryProfession                               knownForTitles
# 0          actor,producer,writer      tt0106057,tt0250687,tt0313443,tt2528814
# 1          actor,producer,writer      tt0113313,tt0295701,tt0097647,tt0120877
# 2                          actor      tt1161064,tt0190374,tt0111127,tt0103956
# ...

# %%
actores_accion_detalles.to_csv('actores_accion_detalles.csv', index=False)

# %%
df_comedia = pd.read_csv('actores_comedia.csv')

# %%
df_combined_d = pd.merge(df_comedia, data, left_on='nconst', right_on='nconst', how='inner')

# %%
actores_comedia_detalles = df_combined_d[['primaryName', 'birthYear', 'deathYear', 'primaryProfession','knownForTitles']]

# %%
actores_comedia_detalles
# Out:
#              primaryName birthYear deathYear  \
# 0         Michael Muhney      1975        \N
# 1          Mary Kay Cook        \N        \N
# 2            Jon Collins        \N        \N
# 3          Jimmy Slonina        \N        \N
# 4          Paul Provenza      1957        \N
# ...                  ...       ...       ...
# 17765    Daniela Terreri      1965        \N
# 17766  Dukagjin Podrimaj      1986        \N
# 17767    Edita Sllamniku        \N        \N
# 17768      Muhamed Arifi        \N        \N
# 17769   Shkumbin Istrefi      1969        \N
#
#                          primaryProfession  \
# 0                    actor,writer,producer
# 1      production_manager,actress,producer
# 2             producer,miscellaneous,actor
# 3                  actor,producer,director
# 4                    actor,producer,writer
# ...                                    ...
# 17765                              actress
# 17766                       actor,producer
# ...

# %%
actores_comedia_detalles.to_csv('actores_comedia_detalles.csv', index=False)

# %%
df_drama = pd.read_csv('actores_drama.csv')

# %%
df_combined_drama = pd.merge(df_drama, data, left_on='nconst', right_on='nconst', how='inner')

# %%
actores_drama_detalles = df_combined_drama[['primaryName', 'birthYear', 'deathYear', 'primaryProfession','knownForTitles']]

# %%
actores_drama_detalles.to_csv('actores_drama_detalles.csv', index=False)
